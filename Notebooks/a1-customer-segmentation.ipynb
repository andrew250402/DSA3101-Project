# %% [markdown]
# # 1. Loading Packages and Datasets

# %%
# Mounting the google drive
from google.colab import drive
import os
drive.mount('/content/drive')
os.listdir('/content/drive/MyDrive/DSA3101 Group Project/')
# Out:
# Mounted at /content/drive
# ['THE PLAYBOOK.pdf',
#  'Meeting Minutes',
#  'Video Script.gdoc',
#  'DSA3101 Group 2 Contributions (Video).gsheet',
#  'Customer Segmentation',
#  'Tables Explanation.gsheet',
#  'Project 3 Requirements.gdoc']

# %%
# Loading of packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import matplotlib.lines as mlines

from sklearn.cluster import AgglomerativeClustering, Birch
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from scipy.cluster.hierarchy import linkage, dendrogram
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
# Importing of datasets

# Specify the correct path
file_path_1= '/content/drive/My Drive/DSA3101 Group Project/Customer Segmentation/Dataset/transactions_summary.csv'
file_path_2= '/content/drive/My Drive/DSA3101 Group Project/Customer Segmentation/Dataset/digital_usage.csv'
file_path_3= '/content/drive/My Drive/DSA3101 Group Project/Customer Segmentation/Dataset/customers.csv'

# Load the datasets
Transaction = pd.read_csv(file_path_1)
Usage = pd.read_csv(file_path_2)
Customers = pd.read_csv(file_path_3)

# Check the columns of the datasets
print(Transaction.columns)
print(Usage.columns)
print(Customers.columns)
# Out:
# Index(['customer_id', 'days_since_last_transaction', 'current_balance',
#        'peak_month', 'peak_month_spending', 'peak_month_frequency',
#        'total_transactions_3m', 'total_transactions_6m',
#        'total_transactions_12m', 'total_transaction_amount_3m',
#        'total_transaction_amount_6m', 'total_transaction_amount_12m',
#        'average_transaction_amount_3m', 'average_transaction_amount_6m',
#        'average_transaction_amount_12m', 'transaction_frequency_3m',
#        'transaction_frequency_6m', 'transaction_frequency_12m',
#        'high_value_transaction_rate_3m', 'high_value_transaction_rate_6m',
#        'high_value_transaction_rate_12m', 'online_transaction_ratio_3m',
#        'online_transaction_ratio_6m', 'online_transaction_ratio_12m'],
#       dtype='object')
# Index(['customer_id', 'has_mobile_app', 'has_web_account',
#        'mobile_logins_per_week', 'web_logins_per_week',
#        'avg_mobile_session_duration', 'avg_web_session_duration',
#        'last_mobile_login', 'last_web_login'],
#       dtype='object')
# Index(['customer_id', 'age', 'job', 'marital', 'education', 'credit_default',
#        'customer_segment', 'region', 'income', 'created_at', 'credit_card',
#        'personal_loan', 'mortgage', 'savings_account', 'investment_product',
#        'auto_loan', 'wealth_management'],
#       dtype='object')

# %% [markdown]
# # 2. Cleaning and Preprocessing Datasets
#
# Now, we will clean the datasets before merging, starting off with the Usage dataset.

# %%
# Cleaning the Usage dataset
# Check for missing values
# print(Usage.isnull().sum())

# Check for 0 values in the datasets
# print((Usage == 0).sum())

# Check if Usage dataset is clean
print(Usage.describe())

# Check if last_mobile_login is null, the mobile_logins_per_week is 0, avg_mobile_session_duration is 0, and has_mobile_app is No
sum_mobile_null = Usage['last_mobile_login'].isnull().sum()
print(sum_mobile_null) # 1659
sum_mobile = 0
for _, row in Usage.iterrows():
    if row['has_mobile_app'] == 'No' and pd.isnull(row['last_mobile_login']) and row['mobile_logins_per_week'] == 0 and row['avg_mobile_session_duration'] == 0:
        sum_mobile += 1
print(sum_mobile) # 1659, the number matches as expected

# Check if last_web_login is null, the web_logins_per_week is 0, avg_web_session_duration is 0, and has_web_account is No
sum_web_null = Usage['last_web_login'].isnull().sum()
print(sum_web_null) # 1539
sum_web = 0
for _, row in Usage.iterrows():
    if row['has_web_account'] == 'No' and pd.isnull(row['last_web_login']) and row['web_logins_per_week'] == 0 and row['avg_web_session_duration'] == 0:
        sum_web += 1
print(sum_web) # 1539, the number matches as expected

# Check if last_mobile_login is null, the sum of mobile_logins_per_week is 0, avg_mobile_session_duration is 0, and has_mobile_app is No
sum_mobile = 0
for _, row in Usage.iterrows():
    if pd.isnull(row['last_mobile_login']):
        sum_mobile += row['mobile_logins_per_week'] + row['avg_mobile_session_duration'] + (1 if row['has_mobile_app'] == 'Yes' else 0)
print(sum_mobile) # 0, the number matches as expected

# Check if last_web_login is null, the sum of web_logins_per_week is 0, avg_web_session_duration is 0, and has_web_account is No
sum_web = 0
for _, row in Usage.iterrows():
    if pd.isnull(row['last_web_login']):
        sum_web += row['web_logins_per_week'] + row['avg_web_session_duration'] + (1 if row['has_web_account'] == 'Yes' else 0)
print(sum_web) # 0, the number matches as expected

# Changing Yes/No response to numerical response
columns_to_convert = ['has_mobile_app', 'has_web_account']
Usage[columns_to_convert] = Usage[columns_to_convert].replace({'Yes': 1, 'No': 0})

# Remove the last web/app log in
Usage = Usage.drop(columns=['last_mobile_login', 'last_web_login'])

print(Usage.head())
# Out:
#        customer_id  mobile_logins_per_week  web_logins_per_week  \
# count  10000.00000            10000.000000          10000.00000
# mean    5000.50000                6.458500              5.06760
# std     2886.89568                3.546764              2.63684
# min        1.00000                0.000000              0.00000
# 25%     2500.75000                5.000000              4.00000
# 50%     5000.50000                7.000000              5.00000
# 75%     7500.25000                9.000000              7.00000
# max    10000.00000               14.000000             11.00000
#
#        avg_mobile_session_duration  avg_web_session_duration
# count                 10000.000000              10000.000000
# mean                      3.030540                  4.471440
# std                       1.964464                  2.674307
# min                       0.000000                  0.000000
# 25%                       1.600000                  2.800000
# 50%                       3.200000                  4.800000
# 75%                       4.500000                  6.400000
# max                       9.200000                 12.200000
# 1659
# 1659
# 1539
# 1539
# 0.0
# 0.0
#    customer_id  has_mobile_app  has_web_account  mobile_logins_per_week  \
# 0            1               1                1                      10
# 1            2               1                1                       9
# 2            3               1                1                       6
# 3            4               1                1                       6
# 4            5               1                1                      11
#
#    web_logins_per_week  avg_mobile_session_duration  avg_web_session_duration
# 0                    5                          3.5                       6.1
# 1                    4                          4.5                       3.9
# 2                   10                          2.5                       5.4
# 3                    8                          3.0                       6.8
# 4                    6                          1.3                       1.6
# <ipython-input-34-82b0caf5de5c>:45: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Usage[columns_to_convert] = Usage[columns_to_convert].replace({'Yes': 1, 'No': 0})

# %% [markdown]
# This shows that the Usage dataset is clean. Now we will check if the Transaction dataset is clean.

# %%
# Cleaning the Transaction dataset
# Check for missing values
# print(Transaction.isnull().sum()) # 0

# Check for 0 values in the dataset
# print((Transaction == 0).sum()) # Multiple 0 values in the dataset

# Check the Statistics of the dataset
# print(Transaction.describe()) # Negative Balance, negative peak_month_spending, 0 values in the dataset

# Remove all the negative rows in the dataset
Transaction = Transaction[Transaction['current_balance'] >= 0]
Transaction = Transaction[Transaction['peak_month_spending'] >= 0]

print(Transaction.describe())

# Shape of the dataset
print(Transaction.shape) # 9940 rows and 24 columns

# Find the rows where average_transaction_amount_12m is 0
zero_avg_transaction = Transaction[Transaction['average_transaction_amount_12m'] == 0]
# Show in table format
display(zero_avg_transaction)
# Out:
#         customer_id  days_since_last_transaction  current_balance  \
# count   9940.000000                  9940.000000      9940.000000
# mean    5000.387827                    23.904527      6835.469185
# std     2885.720548                    36.112473      4657.206812
# min        1.000000                     0.000000         0.000000
# 25%     2501.750000                     5.000000      3670.094710
# 50%     4999.500000                    14.000000      5884.822167
# 75%     7499.250000                    26.000000      8863.982631
# max    10000.000000                   200.000000     39748.029652
#
#         peak_month  peak_month_spending  peak_month_frequency  \
# count  9940.000000          9940.000000           9940.000000
# mean      6.613380         16752.335891             43.036519
# std       3.579621         17618.017033             11.596799
# min       1.000000             0.000000             12.000000
# 25%       3.000000          6019.524591             37.000000
# 50%       7.000000         11807.830133             44.000000
# 75%      10.000000         21356.305352             51.000000
# max      12.000000        282205.767182             77.000000
#
#        total_transactions_3m  total_transactions_6m  total_transactions_12m  \
# count            9940.000000            9940.000000             9940.000000
# mean               98.061771             196.416499              401.161167
# std                34.219191              66.956912              101.883694
# min                 0.000000               0.000000              104.000000
# 25%                80.000000             161.000000              353.000000
# 50%               100.000000             200.000000              413.000000
# 75%               120.000000             239.000000              464.000000
# max               220.000000             472.000000              681.000000
#
#        total_transaction_amount_3m  ...  average_transaction_amount_12m  \
# count                  9940.000000  ...                     9940.000000
# mean                  18346.922341  ...                      192.318259
# std                   15149.068568  ...                      166.745994
# min                       0.000000  ...                        0.000000
# 25%                    7951.435827  ...                       86.223191
# 50%                   15322.038311  ...                      149.453467
# 75%                   23300.934875  ...                      246.037271
# max                  113808.191909  ...                     2779.916745
#
#        transaction_frequency_3m  transaction_frequency_6m  \
# count               9940.000000               9940.000000
# mean                  32.687257                 32.736083
# std                   11.406397                 11.159485
# min                    0.000000                  0.000000
# 25%                   26.666667                 26.833333
# 50%                   33.333333                 33.333333
# 75%                   40.000000                 39.833333
# max                   73.333333                 78.666667
#
#        transaction_frequency_12m  high_value_transaction_rate_3m  \
# count                9940.000000                     9940.000000
# mean                   33.430097                        0.091223
# std                     8.490308                        0.044714
# min                     8.666667                        0.000000
# 25%                    29.416667                        0.060241
# 50%                    34.416667                        0.089552
# 75%                    38.666667                        0.120000
# max                    56.750000                        0.294118
#
#        high_value_transaction_rate_6m  high_value_transaction_rate_12m  \
# count                     9940.000000                      9940.000000
# mean                         0.091793                         0.093459
# std                          0.039144                         0.033226
# min                          0.000000                         0.012903
# 25%                          0.064706                         0.068060
# 50%                          0.089623                         0.090909
# 75%                          0.117931                         0.115385
# max                          0.239865                         0.240991
#
#        online_transaction_ratio_3m  online_transaction_ratio_6m  \
# count                  9940.000000                  9940.000000
# mean                      0.625378                     0.627793
# std                       0.132259                     0.127022
# min                       0.000000                     0.000000
# 25%                       0.596206                     0.598601
# 50%                       0.651625                     0.652030
# 75%                       0.696704                     0.697260
# max                       0.864804                     0.866541
#
#        online_transaction_ratio_12m
# count                   9940.000000
# mean                       0.641855
# std                        0.083767
# min                        0.298947
# 25%                        0.603974
# 50%                        0.653523
# 75%                        0.697740
# max                        0.881280
#
# [8 rows x 24 columns]
# (9940, 24)
#       customer_id  days_since_last_transaction  current_balance  peak_month  \
# 7120         7121                          130              0.0           9
# 8160         8161                            4              0.0           7
#
#       peak_month_spending  peak_month_frequency  total_transactions_3m  \
# 7120                  0.0                    16                      0
# 8160                  0.0                    35                     88
#
#       total_transactions_6m  total_transactions_12m  \
# 7120                    112                     162
# 8160                    171                     320
#
#       total_transaction_amount_3m  ...  average_transaction_amount_12m  \
# 7120                          0.0  ...                             0.0
# 8160                          0.0  ...                             0.0
#
#       transaction_frequency_3m  transaction_frequency_6m  \
# 7120                  0.000000                 18.666667
# 8160                 29.333333                 28.500000
#
#       transaction_frequency_12m  high_value_transaction_rate_3m  \
# 7120                  13.500000                        0.000000
# 8160                  26.666667                        0.034091
#
#       high_value_transaction_rate_6m  high_value_transaction_rate_12m  \
# 7120                        0.098214                         0.049383
# 8160                        0.046784                         0.037500
#
#       online_transaction_ratio_3m  online_transaction_ratio_6m  \
# 7120                     0.000000                     0.470890
# 8160                     0.726451                     0.672533
#
#       online_transaction_ratio_12m
# 7120                      0.510629
# 8160                      0.628687
#
# [2 rows x 24 columns]

# %% [markdown]
# From the above cleaning, we have removed the negative values by eliminating the entire row. We kept the 0 values since there could be a possibility (low) that current balance is 0 and therefore the rest of the transaction information is 0 as well.

# %% [markdown]
# We will now clean the Customer dataset and experiment customer segmentation with just the Customer dataset alone.

# %%
# Load data
customer_data = pd.read_csv(file_path_3)

# Data cleaning and processing
columns_to_convert = ['credit_default', 'credit_card', 'personal_loan', 'mortgage', 'savings_account', 'investment_product', 'auto_loan', 'wealth_management']
customer_data[columns_to_convert] = customer_data[columns_to_convert].replace({'yes': 1, 'no': 0})
customer_data = customer_data[customer_data['income'] >= 0] # Filter out entries with negative income
customer_data = customer_data[customer_data['age'] >= 21] # Filter out non-adults
customer_data = customer_data[customer_data['created_at'] < '2025-03-01'] # Filter out erroneous entries
customer_data = customer_data.drop(columns=['created_at']) # Remove column
customer_data_original = customer_data.copy() # To be used for merging
customer_data = customer_data.drop(columns=['customer_id']) # Remove column

# Show first few entries
customer_data.head()
# Out:
# <ipython-input-36-ec454b8aa82a>:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   customer_data[columns_to_convert] = customer_data[columns_to_convert].replace({'yes': 1, 'no': 0})
#    age          job   marital  education  credit_default  customer_segment  \
# 0   38  blue-collar   married  secondary               0        High-Value
# 2   73     services  divorced  secondary               0  Budget-Conscious
# 3   87      retired   married    primary               0           Retired
# 5   46   technician   married   tertiary               0     Middle-Market
# 6   70        admin   married   tertiary               0  Budget-Conscious
#
#   region  income  credit_card  personal_loan  mortgage  savings_account  \
# 0  Urban    2603            1              1         1                1
# 2  Urban    3130            1              0         0                0
# 3  Urban    2401            1              1         0                1
# 5  Urban    3355            1              1         0                1
# 6  Urban    4918            1              1         1                1
#
#    investment_product  auto_loan  wealth_management
# 0                   1          1                  1
# 2                   1          1                  0
# 3                   0          0                  0
# 5                   0          1                  1
# 6                   0          1                  0

# %% [markdown]
# # 3. Feature Engineering
#
# To handle categorical variables, we first use one-hot encoding to convert them to numerical variables. We then standardise our data using StandardScaler to ensure all feature contribute equally to distance metrics.

# %%
# Create one hot encoding for categorical variables
customer_data_encoded = pd.get_dummies(customer_data)

# Standardise the data
data_scaler = StandardScaler()
scaled_data = data_scaler.fit_transform(customer_data_encoded)
scaled_data.shape
# Out:
# (9429, 34)

# %% [markdown]
# Due to the high number of columns present in the dataset, we shall first use PCA for dimensionality reduction. We then create a Scree Plot to decide how many components we would like to keep in order to retain a high cumulative explained variance of about 95%.

# %%
# Create a Scree Plot to decide the number of components to use
pca = PCA().fit(scaled_data)

plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Scree Plot')
plt.grid()
plt.show()

# %% [markdown]
# # 4. Hierarchical Clustering

# %%
pca = PCA(n_components=25)  # Reduce to 25 dimensions (chosen from Scree Plot)
scaled_data_pca = pca.fit_transform(scaled_data)  # Transform data

# Compute hierarchical clustering
linkage_matrix = linkage(scaled_data_pca, method='ward')  # Ward's method for variance minimisation

# Plot dendrogram
plt.figure(figsize=(10, 5))
dendrogram(linkage_matrix)
plt.axhline(y=150, color='r', linestyle='--')  # Adjust threshold based on the plot
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Samples')
plt.ylabel('Distance')
plt.show()

# %%
# Assign cluster labels (decide number of clusters from dendrogram)
n_clusters = 4
cluster_labels = AgglomerativeClustering(n_clusters=n_clusters, linkage='ward').fit_predict(scaled_data_pca)

print(f"Cluster assignments: {np.unique(cluster_labels, return_counts=True)}")
cluster_labels
# Out:
# Cluster assignments: (array([0, 1, 2, 3]), array([1809, 6291,  781,  548]))
# array([1, 1, 2, ..., 1, 2, 1])

# %%
# Merge cluster labels with the customer dataset
customer_data_with_labels = customer_data
customer_data_with_labels['cluster'] = cluster_labels

# Count the numbers in each cluster
customer_data_with_labels['cluster'].value_counts()
# Out:
# cluster
# 1    6291
# 0    1809
# 2     781
# 3     548
# Name: count, dtype: int64

# %%
# Find the most common traits of each cluster, and count of each traits
unique_traits = {}
for cluster_id in range(n_clusters):
    cluster_data = customer_data_with_labels[customer_data_with_labels['cluster'] == cluster_id]
    unique_traits[cluster_id] = cluster_data.drop(columns=['cluster']).mode().iloc[0]
    print(f"Cluster {cluster_id}:")
    print(unique_traits[cluster_id])
    print()
    print(f"Number of customers in cluster {cluster_id}: {len(cluster_data)}")
    print()
# Out:
# Cluster 0:
# age                              43
# job                      management
# marital                     married
# education                  tertiary
# credit_default                    0
# customer_segment      Middle-Market
# region                        Urban
# income                         6753
# credit_card                       1
# personal_loan                     1
# mortgage                          1
# savings_account                   1
# investment_product                1
# auto_loan                         1
# wealth_management                 0
# Name: 0, dtype: object
#
# Number of customers in cluster 0: 1809
#
# Cluster 1:
# age                            46.0
# job                     blue-collar
# marital                     married
# education                 secondary
# credit_default                  0.0
# customer_segment      Middle-Market
# region                        Urban
# income                         2628
# credit_card                     1.0
# personal_loan                   1.0
# mortgage                        1.0
# savings_account                 1.0
# investment_product              0.0
# auto_loan                       1.0
# wealth_management               0.0
# Name: 0, dtype: object
#
# Number of customers in cluster 1: 6291
#
# Cluster 2:
# age                          61
# job                     retired
# marital                 married
# education             secondary
# credit_default                0
# customer_segment        Retired
# region                    Urban
# income                     2270
# credit_card                   1
# personal_loan                 1
# mortgage                      0
# savings_account               1
# investment_product            0
# auto_loan                     1
# wealth_management             0
# Name: 0, dtype: object
#
# Number of customers in cluster 2: 781
#
# Cluster 3:
# age                                    23
# job                               student
# marital                            single
# education                        tertiary
# credit_default                          0
# customer_segment      Young Professionals
# region                              Urban
# income                                729
# credit_card                             1
# personal_loan                           1
# mortgage                                0
# savings_account                         1
# investment_product                      0
# auto_loan                               1
# wealth_management                       0
# Name: 0, dtype: object
#
# Number of customers in cluster 3: 548

# %% [markdown]
# As we can see, cluster 0 is the high-valued, cluster 1 is middle income, cluster 2 is retiree, and cluster 3 is young adults/interns

# %%
# Each cluster statistical distributions

# For cluster 0
cluster_0_data = customer_data_with_labels[customer_data_with_labels['cluster'] == 0]
print('For Cluster 0')
print(cluster_0_data.describe()) # Mean income of $6268

# For cluster 1
cluster_1_data = customer_data_with_labels[customer_data_with_labels['cluster'] == 1]
print('For Cluster 1')
print(cluster_1_data.describe()) # Mean income of $2875

# For cluster 2
cluster_2_data = customer_data_with_labels[customer_data_with_labels['cluster'] == 2]
print('For Cluster 2')
print(cluster_2_data.describe()) # Mean income of $2623

# For cluster 3
cluster_3_data = customer_data_with_labels[customer_data_with_labels['cluster'] == 3]
print('For Cluster 3')
print(cluster_3_data.describe()) # Mean income of $1953
# Out:
# For Cluster 0
#                age  credit_default        income  credit_card  personal_loan  \
# count  1809.000000          1809.0   1809.000000  1809.000000    1809.000000
# mean     45.149807             0.0   6268.793256     0.889994       0.540077
# std      12.067803             0.0   2180.624361     0.312983       0.498529
# min      21.000000             0.0   1519.000000     0.000000       0.000000
# 25%      37.000000             0.0   4808.000000     1.000000       0.000000
# 50%      44.000000             0.0   6263.000000     1.000000       1.000000
# 75%      53.000000             0.0   8053.000000     1.000000       1.000000
# max      99.000000             0.0  14272.000000     1.000000       1.000000
#
#           mortgage  savings_account  investment_product    auto_loan  \
# count  1809.000000      1809.000000         1809.000000  1809.000000
# mean      0.607518         0.906578            0.562189     0.729685
# std       0.488438         0.291103            0.496255     0.444245
# min       0.000000         0.000000            0.000000     0.000000
# 25%       0.000000         1.000000            0.000000     0.000000
# 50%       1.000000         1.000000            1.000000     1.000000
# 75%       1.000000         1.000000            1.000000     1.000000
# max       1.000000         1.000000            1.000000     1.000000
#
#        wealth_management  cluster
# count        1809.000000   1809.0
# mean            0.426755      0.0
# std             0.494743      0.0
# min             0.000000      0.0
# 25%             0.000000      0.0
# 50%             0.000000      0.0
# 75%             1.000000      0.0
# max             1.000000      0.0
# For Cluster 1
#                age  credit_default       income  credit_card  personal_loan  \
# count  6291.000000     6291.000000  6291.000000  6291.000000    6291.000000
# mean     45.311397        0.053092  2875.843586     0.850898       0.635034
# std      10.477722        0.224234  1234.924147     0.356217       0.481459
# min      21.000000        0.000000     0.000000     0.000000       0.000000
# 25%      38.000000        0.000000  2023.500000     1.000000       0.000000
# 50%      45.000000        0.000000  3034.000000     1.000000       1.000000
# 75%      52.000000        0.000000  3700.000000     1.000000       1.000000
# max      99.000000        1.000000  9962.000000     1.000000       1.000000
#
#           mortgage  savings_account  investment_product    auto_loan  \
# count  6291.000000      6291.000000         6291.000000  6291.000000
# mean      0.511683         0.893340            0.290733     0.709108
# std       0.499903         0.308705            0.454137     0.454210
# min       0.000000         0.000000            0.000000     0.000000
# 25%       0.000000         1.000000            0.000000     0.000000
# 50%       1.000000         1.000000            0.000000     1.000000
# 75%       1.000000         1.000000            1.000000     1.000000
# max       1.000000         1.000000            1.000000     1.000000
#
#        wealth_management  cluster
# count        6291.000000   6291.0
# mean            0.222699      1.0
# std             0.416091      0.0
# min             0.000000      1.0
# 25%             0.000000      1.0
# 50%             0.000000      1.0
# 75%             0.000000      1.0
# max             1.000000      1.0
# For Cluster 2
#               age  credit_default       income  credit_card  personal_loan  \
# count  781.000000           781.0   781.000000   781.000000     781.000000
# mean    72.201024             0.0  2623.725992     0.736236       0.603073
# std      9.492739             0.0   874.993347     0.440955       0.489574
# min     48.000000             0.0   802.000000     0.000000       0.000000
# 25%     64.000000             0.0  1970.000000     0.000000       0.000000
# 50%     70.000000             0.0  2532.000000     1.000000       1.000000
# 75%     80.000000             0.0  2992.000000     1.000000       1.000000
# max     99.000000             0.0  8183.000000     1.000000       1.000000
#
#          mortgage  savings_account  investment_product   auto_loan  \
# count  781.000000       781.000000          781.000000  781.000000
# mean     0.423816         0.942382            0.271447    0.519846
# std      0.494479         0.233170            0.444991    0.499926
# min      0.000000         0.000000            0.000000    0.000000
# 25%      0.000000         1.000000            0.000000    0.000000
# 50%      0.000000         1.000000            0.000000    1.000000
# 75%      1.000000         1.000000            1.000000    1.000000
# max      1.000000         1.000000            1.000000    1.000000
#
#        wealth_management  cluster
# count         781.000000    781.0
# mean            0.171575      2.0
# std             0.377252      0.0
# min             0.000000      2.0
# 25%             0.000000      2.0
# 50%             0.000000      2.0
# 75%             0.000000      2.0
# max             1.000000      2.0
# For Cluster 3
#               age  credit_default       income  credit_card  personal_loan  \
# count  548.000000           548.0   548.000000   548.000000     548.000000
# mean    24.468978             0.0  1953.671533     0.671533       0.613139
# std      2.522467             0.0  1480.300052     0.470085       0.487476
# min     21.000000             0.0     0.000000     0.000000       0.000000
# 25%     22.000000             0.0   709.750000     0.000000       0.000000
# 50%     24.000000             0.0  1367.500000     1.000000       1.000000
# 75%     26.250000             0.0  3241.250000     1.000000       1.000000
# max     29.000000             0.0  7517.000000     1.000000       1.000000
#
#          mortgage  savings_account  investment_product   auto_loan  \
# count  548.000000       548.000000          548.000000  548.000000
# mean     0.343066         0.848540            0.255474    0.521898
# std      0.475167         0.358824            0.436526    0.499977
# min      0.000000         0.000000            0.000000    0.000000
# 25%      0.000000         1.000000            0.000000    0.000000
# 50%      0.000000         1.000000            0.000000    1.000000
# 75%      1.000000         1.000000            1.000000    1.000000
# max      1.000000         1.000000            1.000000    1.000000
#
#        wealth_management  cluster
# count         548.000000    548.0
# mean            0.251825      3.0
# std             0.434458      0.0
# min             0.000000      3.0
# 25%             0.000000      3.0
# 50%             0.000000      3.0
# 75%             1.000000      3.0
# max             1.000000      3.0

# %%
# Visualise the different clusters of Age against Income

# Define colors for clusters
colors = ['blue', 'green', 'orange', 'purple']

# Create figure
plt.figure(figsize=(10, 6))

# Scatter plots for each cluster with transparency
plt.scatter(cluster_0_data['income'], cluster_0_data['age'], label='Cluster 0', color=colors[0], alpha=0.5)
plt.scatter(cluster_1_data['income'], cluster_1_data['age'], label='Cluster 1', color=colors[1], alpha=0.5)
plt.scatter(cluster_2_data['income'], cluster_2_data['age'], label='Cluster 2', color=colors[2], alpha=0.5)
plt.scatter(cluster_3_data['income'], cluster_3_data['age'], label='Cluster 3', color=colors[3], alpha=0.5)

# Compute cluster centroids
centroids = np.array([
    [cluster_0_data['income'].mean(), cluster_0_data['age'].mean()],
    [cluster_1_data['income'].mean(), cluster_1_data['age'].mean()],
    [cluster_2_data['income'].mean(), cluster_2_data['age'].mean()],
    [cluster_3_data['income'].mean(), cluster_3_data['age'].mean()]
])

# Plot centroids in respective cluster colors
plt.scatter(centroids[:, 0], centroids[:, 1], color=colors, s=200, marker='X', edgecolors='black')

# Create a custom legend handle for centroids (black color)
centroid_legend = mlines.Line2D([], [], color='black', marker='X', linestyle='None', markersize=10, label='Centroids')

# Add legend with custom centroid handle
plt.xlabel('Income')
plt.ylabel('Age')
plt.title('Income vs. Age for Each Cluster')
plt.legend(handles=[plt.Line2D([0], [0], color=color, marker='o', linestyle='None', markersize=8, label=f'Cluster {i}') for i, color in enumerate(colors)] + [centroid_legend])
plt.show()

# %% [markdown]
# This shows that the hierarchical clustering does a good job in clustering the customers into 4 different segments.

# %% [markdown]
# # 5. KMeans Clustering

# %%
# Find the optimal number of clusters for KMeans
silhouette_scores = []
cluster_range = range(2, 10)  # Start from 3 clusters to max 9 clusters

for n_clusters in cluster_range:
    kmeans = KMeans(n_clusters=n_clusters, random_state=42, n_init=10)
    cluster_labels = kmeans.fit_predict(scaled_data_pca)

    # Calculate Silhouette Score
    silhouette_avg = silhouette_score(scaled_data_pca, cluster_labels)
    silhouette_scores.append(silhouette_avg)

# Plot Silhouette Score
plt.subplot(1, 2, 2)
plt.plot(cluster_range, silhouette_scores, marker='o', color='r')
plt.title('Silhouette Score')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.tight_layout()
plt.show()

# %%
# K-means Clustering
# Apply K-Means with chosen K (K=4)
kmeans = KMeans(n_clusters=4, random_state=42, n_init=10)
cluster_labels = kmeans.fit_predict(scaled_data_pca)

# Add cluster labels to the dataset
customer_data_with_labels_kmean = customer_data
customer_data_with_labels_kmean['Cluster'] = cluster_labels

# Find the most common traits of each cluster, and count of each traits
unique_traits = {}
n_clusters = 4
for cluster_id in range(n_clusters):
    cluster_data = customer_data_with_labels_kmean[customer_data_with_labels_kmean['Cluster'] == cluster_id]
    unique_traits[cluster_id] = cluster_data.drop(columns=['Cluster']).mode().iloc[0]
    print(f"Cluster {cluster_id}:")
    print(unique_traits[cluster_id])
    print()
    print(f"Number of customers in cluster {cluster_id}: {len(cluster_data)}")
    print()

# Each cluster statistical distributions
# For cluster 0
cluster_0_data = customer_data_with_labels_kmean[customer_data_with_labels_kmean['Cluster'] == 0]
print('For Cluster 0')
print(cluster_0_data.describe()) # Mean income of $2685

# For cluster 1
cluster_1_data = customer_data_with_labels_kmean[customer_data_with_labels_kmean['Cluster'] == 1]
print('For Cluster 1')
print(cluster_1_data.describe()) # Mean income of $2954

# For cluster 2
cluster_2_data = customer_data_with_labels_kmean[customer_data_with_labels_kmean['Cluster'] == 2]
print('For Cluster 2')
print(cluster_2_data.describe()) # Mean income of $2703

# For cluster 3
cluster_3_data = customer_data_with_labels_kmean[customer_data_with_labels_kmean['Cluster'] == 3]
print('For Cluster 3')
print(cluster_3_data.describe()) # Mean income of $7289
# Out:
# Cluster 0:
# age                                  25.0
# job                           blue-collar
# marital                            single
# education                       secondary
# credit_default                        0.0
# customer_segment      Young Professionals
# region                              Urban
# income                                729
# credit_card                           1.0
# personal_loan                         1.0
# mortgage                              0.0
# savings_account                       1.0
# investment_product                    0.0
# auto_loan                             1.0
# wealth_management                     0.0
# cluster                               1.0
# Name: 0, dtype: object
#
# Number of customers in cluster 0: 2088
#
# Cluster 1:
# age                              46
# job                     blue-collar
# marital                     married
# education                 secondary
# credit_default                    0
# customer_segment      Middle-Market
# region                        Urban
# income                         3004
# credit_card                       1
# personal_loan                     1
# mortgage                          1
# savings_account                   1
# investment_product                0
# auto_loan                         1
# wealth_management                 0
# cluster                           1
# Name: 0, dtype: object
#
# Number of customers in cluster 1: 5040
#
# Cluster 2:
# age                          61
# job                     retired
# marital                 married
# education             secondary
# credit_default                0
# customer_segment        Retired
# region                    Urban
# income                     2270
# credit_card                   1
# personal_loan                 1
# mortgage                      0
# savings_account               1
# investment_product            0
# auto_loan                     1
# wealth_management             0
# cluster                       2
# Name: 0, dtype: object
#
# Number of customers in cluster 2: 1029
#
# Cluster 3:
# age                           38
# job                   management
# marital                  married
# education               tertiary
# credit_default                 0
# customer_segment      High-Value
# region                     Urban
# income                      6753
# credit_card                    1
# personal_loan                  1
# mortgage                       1
# savings_account                1
# investment_product             1
# auto_loan                      1
# wealth_management              1
# cluster                        0
# Name: 0, dtype: object
#
# Number of customers in cluster 3: 1272
#
# For Cluster 0
#                age  credit_default       income  credit_card  personal_loan  \
# count  2088.000000     2088.000000  2088.000000  2088.000000    2088.000000
# mean     36.964080        0.035920  2685.628831     0.789272       0.624521
# std      12.008029        0.186134  1416.457395     0.407923       0.484362
# min      21.000000        0.000000     0.000000     0.000000       0.000000
# 25%      26.000000        0.000000  1480.250000     1.000000       0.000000
# 50%      36.000000        0.000000  2900.500000     1.000000       1.000000
# 75%      47.000000        0.000000  3697.250000     1.000000       1.000000
# max      71.000000        1.000000  8060.000000     1.000000       1.000000
#
#           mortgage  savings_account  investment_product    auto_loan  \
# count  2088.000000      2088.000000         2088.000000  2088.000000
# mean      0.361590         0.887452            0.294061     0.650862
# std       0.480576         0.316115            0.455729     0.476812
# min       0.000000         0.000000            0.000000     0.000000
# 25%       0.000000         1.000000            0.000000     0.000000
# 50%       0.000000         1.000000            0.000000     1.000000
# 75%       1.000000         1.000000            1.000000     1.000000
# max       1.000000         1.000000            1.000000     1.000000
#
#        wealth_management      cluster  Cluster
# count         2088.00000  2088.000000   2088.0
# mean             0.23659     1.436303      0.0
# std              0.42509     0.967990      0.0
# min              0.00000     0.000000      0.0
# 25%              0.00000     1.000000      0.0
# 50%              0.00000     1.000000      0.0
# 75%              0.00000     3.000000      0.0
# max              1.00000     3.000000      0.0
# For Cluster 1
#                age  credit_default       income  credit_card  personal_loan  \
# count  5040.000000     5040.000000  5040.000000  5040.000000    5040.000000
# mean     45.356151        0.035913  2954.488492     0.861508       0.636111
# std       9.185631        0.186091  1196.138361     0.345450       0.481165
# min      21.000000        0.000000     0.000000     0.000000       0.000000
# 25%      38.000000        0.000000  2142.750000     1.000000       0.000000
# 50%      45.000000        0.000000  3105.000000     1.000000       1.000000
# 75%      52.000000        0.000000  3771.250000     1.000000       1.000000
# max      95.000000        1.000000  9399.000000     1.000000       1.000000
#
#           mortgage  savings_account  investment_product    auto_loan  \
# count  5040.000000      5040.000000         5040.000000  5040.000000
# mean      0.563294         0.896032            0.302183     0.719841
# std       0.496027         0.305250            0.459249     0.449121
# min       0.000000         0.000000            0.000000     0.000000
# 25%       0.000000         1.000000            0.000000     0.000000
# 50%       1.000000         1.000000            0.000000     1.000000
# 75%       1.000000         1.000000            1.000000     1.000000
# max       1.000000         1.000000            1.000000     1.000000
#
#        wealth_management      cluster  Cluster
# count        5040.000000  5040.000000   5040.0
# mean            0.221627     0.935714      1.0
# std             0.415383     0.256362      0.0
# min             0.000000     0.000000      1.0
# 25%             0.000000     1.000000      1.0
# 50%             0.000000     1.000000      1.0
# 75%             0.000000     1.000000      1.0
# max             1.000000     3.000000      1.0
# For Cluster 2
#                age  credit_default       income  credit_card  personal_loan  \
# count  1029.000000     1029.000000  1029.000000  1029.000000    1029.000000
# mean     71.367347        0.045675  2703.285714     0.734694       0.592809
# std       9.578325        0.208882  1112.305315     0.441711       0.491550
# min      60.000000        0.000000    40.000000     0.000000       0.000000
# 25%      63.000000        0.000000  1973.000000     0.000000       0.000000
# 50%      68.000000        0.000000  2592.000000     1.000000       1.000000
# 75%      78.000000        0.000000  3224.000000     1.000000       1.000000
# max      99.000000        1.000000  9210.000000     1.000000       1.000000
#
#           mortgage  savings_account  investment_product    auto_loan  \
# count  1029.000000      1029.000000         1029.000000  1029.000000
# mean      0.412051         0.920311            0.258503     0.534500
# std       0.492443         0.270943            0.438025     0.499051
# min       0.000000         0.000000            0.000000     0.000000
# 25%       0.000000         1.000000            0.000000     0.000000
# 50%       0.000000         1.000000            0.000000     1.000000
# 75%       1.000000         1.000000            1.000000     1.000000
# max       1.000000         1.000000            1.000000     1.000000
#
#        wealth_management      cluster  Cluster
# count        1029.000000  1029.000000   1029.0
# mean            0.181730     1.696793      2.0
# std             0.385809     0.576282      0.0
# min             0.000000     0.000000      2.0
# 25%             0.000000     2.000000      2.0
# 50%             0.000000     2.000000      2.0
# 75%             0.000000     2.000000      2.0
# max             1.000000     2.000000      2.0
# For Cluster 3
#                age  credit_default        income  credit_card  personal_loan  \
# count  1272.000000     1272.000000   1272.000000   1272.00000    1272.000000
# mean     45.058962        0.024371   7289.327830      0.91195       0.518082
# std      11.421975        0.154259   1716.198495      0.28348       0.499869
# min      21.000000        0.000000   1552.000000      0.00000       0.000000
# 25%      37.000000        0.000000   6092.250000      1.00000       0.000000
# 50%      44.000000        0.000000   7360.500000      1.00000       1.000000
# 75%      52.000000        0.000000   8680.250000      1.00000       1.000000
# max      98.000000        1.000000  14272.000000      1.00000       1.000000
#
#           mortgage  savings_account  investment_product    auto_loan  \
# count  1272.000000      1272.000000         1272.000000  1272.000000
# mean      0.643868         0.900157            0.625000     0.735849
# std       0.479043         0.299908            0.484313     0.441053
# min       0.000000         0.000000            0.000000     0.000000
# 25%       0.000000         1.000000            0.000000     0.000000
# 50%       1.000000         1.000000            1.000000     1.000000
# 75%       1.000000         1.000000            1.000000     1.000000
# max       1.000000         1.000000            1.000000     1.000000
#
#        wealth_management      cluster  Cluster
# count        1272.000000  1272.000000   1272.0
# mean            0.508648     0.028302      3.0
# std             0.500122     0.165899      0.0
# min             0.000000     0.000000      3.0
# 25%             0.000000     0.000000      3.0
# 50%             1.000000     0.000000      3.0
# 75%             1.000000     0.000000      3.0
# max             1.000000     1.000000      3.0

# %%
# Visualise the different clusters of Age against Income

# Define colors for clusters
colors = ['blue', 'green', 'orange', 'purple']

# Create figure
plt.figure(figsize=(10, 6))

# Scatter plots for each cluster with transparency
plt.scatter(cluster_0_data['income'], cluster_0_data['age'], label='Cluster 0', color=colors[0], alpha=0.5)
plt.scatter(cluster_1_data['income'], cluster_1_data['age'], label='Cluster 1', color=colors[1], alpha=0.5)
plt.scatter(cluster_2_data['income'], cluster_2_data['age'], label='Cluster 2', color=colors[2], alpha=0.5)
plt.scatter(cluster_3_data['income'], cluster_3_data['age'], label='Cluster 3', color=colors[3], alpha=0.5)

# Compute cluster centroids
centroids = np.array([
    [cluster_0_data['income'].mean(), cluster_0_data['age'].mean()],
    [cluster_1_data['income'].mean(), cluster_1_data['age'].mean()],
    [cluster_2_data['income'].mean(), cluster_2_data['age'].mean()],
    [cluster_3_data['income'].mean(), cluster_3_data['age'].mean()]
])

# Plot centroids in respective cluster colors
plt.scatter(centroids[:, 0], centroids[:, 1], color=colors, s=200, marker='X', edgecolors='black')

# Create a custom legend handle for centroids (black color)
centroid_legend = mlines.Line2D([], [], color='black', marker='X', linestyle='None', markersize=10, label='Centroids')

# Add legend with custom centroid handle
plt.xlabel('Income')
plt.ylabel('Age')
plt.title('Income vs. Age for Each Cluster')
plt.legend(handles=[plt.Line2D([0], [0], color=color, marker='o', linestyle='None', markersize=8, label=f'Cluster {i}') for i, color in enumerate(colors)] + [centroid_legend])
plt.show()

# %% [markdown]
# Both KMeans and Hierarchical clustering have shown to have segment the customers effectively based on the scatter plots. We will now merge the customer dataset with transaction and usage dataset and implement the same models as above

# %%
# Merge the datasets
df = pd.merge(customer_data_original, Transaction, on='customer_id', how='inner')
df = pd.merge(df, Usage, on='customer_id', how='inner')

# Check the shape of the merge dataset
print(df.shape) # 9429 rows
print(df.columns)
# Out:
# (9429, 45)
# Index(['customer_id', 'age', 'job', 'marital', 'education', 'credit_default',
#        'customer_segment', 'region', 'income', 'credit_card', 'personal_loan',
#        'mortgage', 'savings_account', 'investment_product', 'auto_loan',
#        'wealth_management', 'days_since_last_transaction', 'current_balance',
#        'peak_month', 'peak_month_spending', 'peak_month_frequency',
#        'total_transactions_3m', 'total_transactions_6m',
#        'total_transactions_12m', 'total_transaction_amount_3m',
#        'total_transaction_amount_6m', 'total_transaction_amount_12m',
#        'average_transaction_amount_3m', 'average_transaction_amount_6m',
#        'average_transaction_amount_12m', 'transaction_frequency_3m',
#        'transaction_frequency_6m', 'transaction_frequency_12m',
#        'high_value_transaction_rate_3m', 'high_value_transaction_rate_6m',
#        'high_value_transaction_rate_12m', 'online_transaction_ratio_3m',
#        'online_transaction_ratio_6m', 'online_transaction_ratio_12m',
#        'has_mobile_app', 'has_web_account', 'mobile_logins_per_week',
#        'web_logins_per_week', 'avg_mobile_session_duration',
#        'avg_web_session_duration'],
#       dtype='object')

# %%
# Remove 'customer_id' column
df = df.drop('customer_id', axis=1)

# Identify categorical columns
categorical_cols = df.select_dtypes(include=['object']).columns

# Apply One-Hot Encoding
df_encoded = pd.get_dummies(df, columns=categorical_cols, drop_first=True)
print(df_encoded.head())

# Standardise the data
data_scaler = StandardScaler()
scaled_data = data_scaler.fit_transform(df_encoded)
scaled_data.shape # 9429 Rows
# Out:
#    age  credit_default  income  credit_card  personal_loan  mortgage  \
# 0   38               0    2603            1              1         1
# 1   73               0    3130            1              0         0
# 2   87               0    2401            1              1         0
# 3   46               0    3355            1              1         0
# 4   70               0    4918            1              1         1
#
#    savings_account  investment_product  auto_loan  wealth_management  ...  \
# 0                1                   1          1                  1  ...
# 1                0                   1          1                  0  ...
# 2                1                   0          0                  0  ...
# 3                1                   0          1                  1  ...
# 4                1                   0          1                  0  ...
#
#    marital_married  marital_single  education_secondary  education_tertiary  \
# 0             True           False                 True               False
# 1            False           False                 True               False
# 2             True           False                False               False
# 3             True           False                False                True
# 4             True           False                False                True
#
#    customer_segment_High-Value  customer_segment_Middle-Market  \
# 0                         True                           False
# 1                        False                           False
# 2                        False                           False
# 3                        False                            True
# 4                        False                           False
#
#    customer_segment_Retired  customer_segment_Young Professionals  \
# 0                     False                                 False
# 1                     False                                 False
# 2                      True                                 False
# 3                     False                                 False
# 4                     False                                 False
#
#    region_Suburban  region_Urban
# 0            False          True
# 1            False          True
# 2            False          True
# 3            False          True
# 4            False          True
#
# [5 rows x 58 columns]
# (9429, 58)

# %%
# Create a Scree Plot to decide the number of components to use
pca = PCA().fit(scaled_data)

plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Scree Plot')
plt.grid()
plt.show()

# %%
pca = PCA(n_components=40)  # Reduce to 40 dimensions (chosen from Scree Plot)
scaled_data_pca = pca.fit_transform(scaled_data)  # Transform data

# Compute hierarchical clustering
linkage_matrix = linkage(scaled_data_pca, method='ward')  # Ward's method for variance minimisation

# Plot dendrogram
plt.figure(figsize=(10, 5))
dendrogram(linkage_matrix)
plt.axhline(y=250, color='r', linestyle='--')  # Adjust threshold based on the plot
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Samples')
plt.ylabel('Distance')
plt.show()

# %%
# Assign cluster labels (decide number of clusters from dendrogram)
n_clusters = 3
cluster_labels = AgglomerativeClustering(n_clusters=n_clusters, linkage='ward').fit_predict(scaled_data_pca)

print(f"Cluster assignments: {np.unique(cluster_labels, return_counts=True)}")
cluster_labels
# Out:
# Cluster assignments: (array([0, 1, 2]), array([2244, 5862, 1323]))
# array([1, 0, 0, ..., 0, 0, 1])

# %%
# Merge cluster labels with the customer dataset
customer_data_with_labels = df
customer_data_with_labels['cluster'] = cluster_labels

# Count the numbers in each cluster
customer_data_with_labels['cluster'].value_counts()
# Out:
# cluster
# 1    5862
# 0    2244
# 2    1323
# Name: count, dtype: int64

# %%
# Find the most common traits of each cluster, and count of each traits
unique_traits = {}
for cluster_id in range(n_clusters):
    cluster_data = customer_data_with_labels[customer_data_with_labels['cluster'] == cluster_id]
    unique_traits[cluster_id] = cluster_data.drop(columns=['cluster']).mode().iloc[0]
    print(f"Cluster {cluster_id}:")
    print(unique_traits[cluster_id])
    print()
    print(f"Number of customers in cluster {cluster_id}: {len(cluster_data)}")
    print()
# Out:
# Cluster 0:
# age                                     61.0
# job                                  retired
# marital                              married
# education                          secondary
# credit_default                           0.0
# customer_segment                     Retired
# region                                 Urban
# income                                2270.0
# credit_card                              1.0
# personal_loan                            1.0
# mortgage                                 0.0
# savings_account                          1.0
# investment_product                       0.0
# auto_loan                                1.0
# wealth_management                        0.0
# days_since_last_transaction              0.0
# current_balance                          0.0
# peak_month                              12.0
# peak_month_spending                      0.0
# peak_month_frequency                    28.0
# total_transactions_3m                    0.0
# total_transactions_6m                    0.0
# total_transactions_12m                 130.0
# total_transaction_amount_3m              0.0
# total_transaction_amount_6m              0.0
# total_transaction_amount_12m             0.0
# average_transaction_amount_3m            0.0
# average_transaction_amount_6m            0.0
# average_transaction_amount_12m           0.0
# transaction_frequency_3m                 0.0
# transaction_frequency_6m                 0.0
# transaction_frequency_12m          10.833333
# high_value_transaction_rate_3m           0.0
# high_value_transaction_rate_6m           0.0
# high_value_transaction_rate_12m     0.076923
# online_transaction_ratio_3m              0.0
# online_transaction_ratio_6m              0.0
# online_transaction_ratio_12m        0.298947
# has_mobile_app                           1.0
# has_web_account                          1.0
# mobile_logins_per_week                   0.0
# web_logins_per_week                      8.0
# avg_mobile_session_duration              0.0
# avg_web_session_duration                 0.0
# Name: 0, dtype: object
#
# Number of customers in cluster 0: 2244
#
# Cluster 1:
# age                                         46.0
# job                                  blue-collar
# marital                                  married
# education                              secondary
# credit_default                               0.0
# customer_segment                   Middle-Market
# region                                     Urban
# income                                    2628.0
# credit_card                                  1.0
# personal_loan                                1.0
# mortgage                                     1.0
# savings_account                              1.0
# investment_product                           0.0
# auto_loan                                    1.0
# wealth_management                            0.0
# days_since_last_transaction                  0.0
# current_balance                      1037.630557
# peak_month                                  12.0
# peak_month_spending                  1130.697611
# peak_month_frequency                        44.0
# total_transactions_3m                      101.0
# total_transactions_6m                      224.0
# total_transactions_12m                     416.0
# total_transaction_amount_3m          2990.790815
# total_transaction_amount_6m          4345.109853
# total_transaction_amount_12m         5608.277385
# average_transaction_amount_3m          41.408125
# average_transaction_amount_6m          23.344281
# average_transaction_amount_12m         14.491673
# transaction_frequency_3m               33.666667
# transaction_frequency_6m               37.333333
# transaction_frequency_12m              34.666667
# high_value_transaction_rate_3m          0.090909
# high_value_transaction_rate_6m          0.090909
# high_value_transaction_rate_12m         0.083333
# online_transaction_ratio_3m             0.443685
# online_transaction_ratio_6m             0.457831
# online_transaction_ratio_12m            0.456233
# has_mobile_app                               1.0
# has_web_account                              1.0
# mobile_logins_per_week                       6.0
# web_logins_per_week                          5.0
# avg_mobile_session_duration                  0.0
# avg_web_session_duration                     0.0
# Name: 0, dtype: object
#
# Number of customers in cluster 1: 5862
#
# Cluster 2:
# age                                         38.0
# job                                   management
# marital                                  married
# education                               tertiary
# credit_default                               0.0
# customer_segment                   Middle-Market
# region                                     Urban
# income                                    6377.0
# credit_card                                  1.0
# personal_loan                                1.0
# mortgage                                     1.0
# savings_account                              1.0
# investment_product                           1.0
# auto_loan                                    1.0
# wealth_management                            0.0
# days_since_last_transaction                  0.0
# current_balance                      1791.460858
# peak_month                                  12.0
# peak_month_spending                  3816.689936
# peak_month_frequency                        63.0
# total_transactions_3m                      108.0
# total_transactions_6m                      277.0
# total_transactions_12m                     526.0
# total_transaction_amount_3m          8678.456944
# total_transaction_amount_6m         11726.197129
# total_transaction_amount_12m        19467.350649
# average_transaction_amount_3m          77.773933
# average_transaction_amount_6m          34.965783
# average_transaction_amount_12m         36.805618
# transaction_frequency_3m                    36.0
# transaction_frequency_6m               46.166667
# transaction_frequency_12m              43.833333
# high_value_transaction_rate_3m          0.142857
# high_value_transaction_rate_6m               0.1
# high_value_transaction_rate_12m         0.142857
# online_transaction_ratio_3m             0.432408
# online_transaction_ratio_6m             0.389979
# online_transaction_ratio_12m            0.447084
# has_mobile_app                               1.0
# has_web_account                              1.0
# mobile_logins_per_week                       7.0
# web_logins_per_week                          5.0
# avg_mobile_session_duration                  0.0
# avg_web_session_duration                     0.0
# Name: 0, dtype: object
#
# Number of customers in cluster 2: 1323

# %%
# Each cluster statistical distributions

# For cluster 0
cluster_0_data = customer_data_with_labels[customer_data_with_labels['cluster'] == 0]
print('For Cluster 0')
print(cluster_0_data.describe()) # Mean income of $2162

# For cluster 1
cluster_1_data = customer_data_with_labels[customer_data_with_labels['cluster'] == 1]
print('For Cluster 1')
print(cluster_1_data.describe()) # Mean income of $3156

# For cluster 2
cluster_2_data = customer_data_with_labels[customer_data_with_labels['cluster'] == 2]
print('For Cluster 2')
print(cluster_2_data.describe()) # Mean income of $6949
# Out:
# For Cluster 0
#                age  credit_default       income  credit_card  personal_loan  \
# count  2244.000000     2244.000000  2244.000000  2244.000000    2244.000000
# mean     55.274955        0.040553  2162.473708     0.712121       0.642602
# std      19.755746        0.197295  1581.974932     0.452875       0.479340
# min      21.000000        0.000000     0.000000     0.000000       0.000000
# 25%      38.000000        0.000000   819.750000     0.000000       0.000000
# 50%      61.000000        0.000000  2044.000000     1.000000       1.000000
# 75%      68.000000        0.000000  3038.000000     1.000000       1.000000
# max      99.000000        1.000000  9967.000000     1.000000       1.000000
#
#           mortgage  savings_account  investment_product    auto_loan  \
# count  2244.000000      2244.000000         2244.000000  2244.000000
# mean      0.442068         0.877005            0.279412     0.555258
# std       0.496743         0.328504            0.448810     0.497048
# min       0.000000         0.000000            0.000000     0.000000
# 25%       0.000000         1.000000            0.000000     0.000000
# 50%       0.000000         1.000000            0.000000     1.000000
# 75%       1.000000         1.000000            1.000000     1.000000
# max       1.000000         1.000000            1.000000     1.000000
#
#        wealth_management  ...  online_transaction_ratio_3m  \
# count        2244.000000  ...                  2244.000000
# mean            0.218360  ...                     0.489386
# std             0.413225  ...                     0.200123
# min             0.000000  ...                     0.000000
# 25%             0.000000  ...                     0.448723
# 50%             0.000000  ...                     0.520415
# 75%             0.000000  ...                     0.619499
# max             1.000000  ...                     0.827326
#
#        online_transaction_ratio_6m  online_transaction_ratio_12m  \
# count                  2244.000000                   2244.000000
# mean                      0.497982                      0.558902
# std                       0.191189                      0.102255
# min                       0.000000                      0.298947
# 25%                       0.448842                      0.477696
# 50%                       0.526158                      0.546807
# 75%                       0.618657                      0.642155
# max                       0.835170                      0.844852
#
#        has_mobile_app  has_web_account  mobile_logins_per_week  \
# count     2244.000000      2244.000000             2244.000000
# mean         0.748663         0.842246                5.512478
# std          0.433878         0.364591                3.694211
# min          0.000000         0.000000                0.000000
# 25%          0.000000         1.000000                0.000000
# 50%          1.000000         1.000000                6.000000
# 75%          1.000000         1.000000                8.000000
# max          1.000000         1.000000               13.000000
#
#        web_logins_per_week  avg_mobile_session_duration  \
# count          2244.000000                  2244.000000
# mean              5.815954                     2.774109
# std               2.942379                     2.080747
# min               0.000000                     0.000000
# 25%               5.000000                     0.000000
# 50%               7.000000                     3.000000
# 75%               8.000000                     4.400000
# max              10.000000                     8.700000
#
#        avg_web_session_duration  cluster
# count               2244.000000   2244.0
# mean                   4.703164      0.0
# std                    2.768702      0.0
# min                    0.000000      0.0
# 25%                    3.000000      0.0
# 50%                    5.100000      0.0
# 75%                    6.700000      0.0
# max                   12.200000      0.0
#
# [8 rows x 40 columns]
# For Cluster 1
#                age  credit_default       income  credit_card  personal_loan  \
# count  5862.000000      5862.00000  5862.000000  5862.000000    5862.000000
# mean     43.201126         0.04060  3156.793927     0.873593       0.620607
# std       9.439214         0.19738  1070.021514     0.332336       0.485277
# min      21.000000         0.00000  1000.000000     0.000000       0.000000
# 25%      36.000000         0.00000  2476.000000     1.000000       0.000000
# 50%      44.000000         0.00000  3204.000000     1.000000       1.000000
# 75%      50.000000         0.00000  3845.000000     1.000000       1.000000
# max      72.000000         1.00000  9962.000000     1.000000       1.000000
#
#           mortgage  savings_account  investment_product    auto_loan  \
# count  5862.000000      5862.000000         5862.000000  5862.000000
# mean      0.516206         0.903787            0.303992     0.726373
# std       0.499780         0.294908            0.460018     0.445858
# min       0.000000         0.000000            0.000000     0.000000
# 25%       0.000000         1.000000            0.000000     0.000000
# 50%       1.000000         1.000000            0.000000     1.000000
# 75%       1.000000         1.000000            1.000000     1.000000
# max       1.000000         1.000000            1.000000     1.000000
#
#        wealth_management  ...  online_transaction_ratio_3m  \
# count        5862.000000  ...                  5862.000000
# mean            0.224156  ...                     0.657300
# std             0.417061  ...                     0.055234
# min             0.000000  ...                     0.443685
# 25%             0.000000  ...                     0.620171
# 50%             0.000000  ...                     0.656628
# 75%             0.000000  ...                     0.693387
# max             1.000000  ...                     0.861424
#
#        online_transaction_ratio_6m  online_transaction_ratio_12m  \
# count                  5862.000000                   5862.000000
# mean                      0.657774                      0.657917
# std                       0.054321                      0.053677
# min                       0.457831                      0.456233
# 25%                       0.621327                      0.622740
# 50%                       0.657312                      0.656807
# 75%                       0.693644                      0.693346
# max                       0.861464                      0.881280
#
#        has_mobile_app  has_web_account  mobile_logins_per_week  \
# count     5862.000000      5862.000000             5862.000000
# mean         0.856704         0.850392                6.493688
# std          0.350404         0.356717                3.353670
# min          0.000000         0.000000                0.000000
# 25%          1.000000         1.000000                5.000000
# 50%          1.000000         1.000000                6.000000
# 75%          1.000000         1.000000                9.000000
# max          1.000000         1.000000               14.000000
#
#        web_logins_per_week  avg_mobile_session_duration  \
# count          5862.000000                   5862.00000
# mean              4.868987                      3.10290
# std               2.484945                      1.92901
# min               0.000000                      0.00000
# 25%               4.000000                      1.80000
# 50%               5.000000                      3.30000
# 75%               6.000000                      4.50000
# max              10.000000                      9.20000
#
#        avg_web_session_duration  cluster
# count               5862.000000   5862.0
# mean                   4.414603      1.0
# std                    2.622139      0.0
# min                    0.000000      1.0
# 25%                    2.800000      1.0
# 50%                    4.700000      1.0
# 75%                    6.300000      1.0
# max                   12.200000      1.0
#
# [8 rows x 40 columns]
# For Cluster 2
#                age  credit_default        income  credit_card  personal_loan  \
# count  1323.000000     1323.000000   1323.000000  1323.000000    1323.000000
# mean     44.781557        0.003779   6949.511716     0.897203       0.528345
# std      11.782762        0.061383   2029.120991     0.303808       0.499385
# min      21.000000        0.000000   1519.000000     0.000000       0.000000
# 25%      37.000000        0.000000   5736.000000     1.000000       0.000000
# 50%      44.000000        0.000000   7109.000000     1.000000       1.000000
# 75%      52.000000        0.000000   8570.000000     1.000000       1.000000
# max      99.000000        1.000000  14272.000000     1.000000       1.000000
#
#           mortgage  savings_account  investment_product    auto_loan  \
# count  1323.000000      1323.000000         1323.000000  1323.000000
# mean      0.619048         0.903250            0.596372     0.732426
# std       0.485805         0.295729            0.490810     0.442861
# min       0.000000         0.000000            0.000000     0.000000
# 25%       0.000000         1.000000            0.000000     0.000000
# 50%       1.000000         1.000000            1.000000     1.000000
# 75%       1.000000         1.000000            1.000000     1.000000
# max       1.000000         1.000000            1.000000     1.000000
#
#        wealth_management  ...  online_transaction_ratio_3m  \
# count        1323.000000  ...                  1323.000000
# mean            0.484505  ...                     0.691541
# std             0.499949  ...                     0.068016
# min             0.000000  ...                     0.432408
# 25%             0.000000  ...                     0.661015
# 50%             0.000000  ...                     0.698928
# 75%             1.000000  ...                     0.735410
# max             1.000000  ...                     0.863008
#
#        online_transaction_ratio_6m  online_transaction_ratio_12m  \
# count                  1323.000000                   1323.000000
# mean                      0.693110                      0.691147
# std                       0.069087                      0.065430
# min                       0.389979                      0.447084
# 25%                       0.659461                      0.659960
# 50%                       0.699848                      0.696603
# 75%                       0.738854                      0.734367
# max                       0.866541                      0.866983
#
#        has_mobile_app  has_web_account  mobile_logins_per_week  \
# count     1323.000000      1323.000000             1323.000000
# mean         0.843537         0.839002                6.969766
# std          0.363431         0.367668                3.747999
# min          0.000000         0.000000                0.000000
# 25%          1.000000         1.000000                6.000000
# 50%          1.000000         1.000000                7.000000
# 75%          1.000000         1.000000               10.000000
# max          1.000000         1.000000               14.000000
#
#        web_logins_per_week  avg_mobile_session_duration  \
# count          1323.000000                  1323.000000
# mean              4.939531                     3.172109
# std               2.633596                     1.993078
# min               0.000000                     0.000000
# 25%               4.000000                     1.800000
# 50%               5.000000                     3.400000
# 75%               7.000000                     4.700000
# max              11.000000                     8.800000
#
#        avg_web_session_duration  cluster
# count               1323.000000   1323.0
# mean                   4.438398      2.0
# std                    2.736298      0.0
# min                    0.000000      2.0
# 25%                    2.600000      2.0
# 50%                    4.800000      2.0
# 75%                    6.450000      2.0
# max                   11.700000      2.0
#
# [8 rows x 40 columns]

# %%
# Visualise the different clusters of Age against Income

# Define colors for clusters
colors = ['blue', 'green', 'orange']

# Create figure
plt.figure(figsize=(10, 6))

# Scatter plots for each cluster with transparency
plt.scatter(cluster_0_data['income'], cluster_0_data['age'], label='Cluster 0', color=colors[0], alpha=0.5)
plt.scatter(cluster_1_data['income'], cluster_1_data['age'], label='Cluster 1', color=colors[1], alpha=0.5)
plt.scatter(cluster_2_data['income'], cluster_2_data['age'], label='Cluster 2', color=colors[2], alpha=0.5)

# Compute cluster centroids
centroids = np.array([
    [cluster_0_data['income'].mean(), cluster_0_data['age'].mean()],
    [cluster_1_data['income'].mean(), cluster_1_data['age'].mean()],
    [cluster_2_data['income'].mean(), cluster_2_data['age'].mean()]
])

# Plot centroids in respective cluster colors
plt.scatter(centroids[:, 0], centroids[:, 1], color=colors, s=200, marker='X', edgecolors='black')

# Create a custom legend handle for centroids (black color)
centroid_legend = mlines.Line2D([], [], color='black', marker='X', linestyle='None', markersize=10, label='Centroids')

# Add legend with custom centroid handle
plt.xlabel('Income')
plt.ylabel('Age')
plt.title('Income vs. Age for Each Cluster')
plt.legend(handles=[plt.Line2D([0], [0], color=color, marker='o', linestyle='None', markersize=8, label=f'Cluster {i}') for i, color in enumerate(colors)] + [centroid_legend])
plt.show()

# %% [markdown]
# Now we will move on to KMeans Clustering

# %%
# Find the optimal number of clusters for KMeans
silhouette_scores = []
cluster_range = range(2, 10)  # Start from 3 clusters to max 9 clusters

for n_clusters in cluster_range:
    kmeans = KMeans(n_clusters=n_clusters, random_state=42, n_init=10)
    cluster_labels = kmeans.fit_predict(scaled_data_pca)

    # Calculate Silhouette Score
    silhouette_avg = silhouette_score(scaled_data_pca, cluster_labels)
    silhouette_scores.append(silhouette_avg)

# Plot Silhouette Score
plt.subplot(1, 2, 2)
plt.plot(cluster_range, silhouette_scores, marker='o', color='r')
plt.title('Silhouette Score')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.tight_layout()
plt.show()

# %%
# K-means Clustering
# Apply K-Means with chosen K (K=3)
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
cluster_labels = kmeans.fit_predict(scaled_data_pca)

# Add cluster labels to the dataset
customer_data_with_labels_kmean = df_encoded
customer_data_with_labels_kmean['Cluster'] = cluster_labels

# Find the most common traits of each cluster, and count of each traits
unique_traits = {}
n_clusters = 3
for cluster_id in range(n_clusters):
    cluster_data = customer_data_with_labels_kmean[customer_data_with_labels_kmean['Cluster'] == cluster_id]
    unique_traits[cluster_id] = cluster_data.drop(columns=['Cluster']).mode().iloc[0]
    print(f"Cluster {cluster_id}:")
    print(unique_traits[cluster_id])
    print()
    print(f"Number of customers in cluster {cluster_id}: {len(cluster_data)}")
    print()

# Each cluster statistical distributions
# For cluster 0
cluster_0_data = customer_data_with_labels_kmean[customer_data_with_labels_kmean['Cluster'] == 0]
print('For Cluster 0')
print(cluster_0_data.describe()) # Mean income of $2986

# For cluster 1
cluster_1_data = customer_data_with_labels_kmean[customer_data_with_labels_kmean['Cluster'] == 1]
print('For Cluster 1')
print(cluster_1_data.describe()) # Mean income of $2154

# For cluster 2
cluster_2_data = customer_data_with_labels_kmean[customer_data_with_labels_kmean['Cluster'] == 2]
print('For Cluster 2')
print(cluster_2_data.describe()) # Mean income of $7109
# Out:
# Cluster 0:
# age                                          46.0
# credit_default                                0.0
# income                                     2628.0
# credit_card                                   1.0
# personal_loan                                 1.0
# mortgage                                      1.0
# savings_account                               1.0
# investment_product                            0.0
# auto_loan                                     1.0
# wealth_management                             0.0
# days_since_last_transaction                   0.0
# current_balance                               0.0
# peak_month                                   12.0
# peak_month_spending                           0.0
# peak_month_frequency                         44.0
# total_transactions_3m                       100.0
# total_transactions_6m                       188.0
# total_transactions_12m                      416.0
# total_transaction_amount_3m                   0.0
# total_transaction_amount_6m                   0.0
# total_transaction_amount_12m                  0.0
# average_transaction_amount_3m                 0.0
# average_transaction_amount_6m                 0.0
# average_transaction_amount_12m                0.0
# transaction_frequency_3m                33.333333
# transaction_frequency_6m                31.333333
# transaction_frequency_12m               34.666667
# high_value_transaction_rate_3m           0.090909
# high_value_transaction_rate_6m           0.090909
# high_value_transaction_rate_12m          0.083333
# online_transaction_ratio_3m                   0.0
# online_transaction_ratio_6m                   0.0
# online_transaction_ratio_12m             0.424936
# has_mobile_app                                1.0
# has_web_account                               1.0
# mobile_logins_per_week                        6.0
# web_logins_per_week                           5.0
# avg_mobile_session_duration                   0.0
# avg_web_session_duration                      0.0
# job_blue-collar                             False
# job_entrepreneur                            False
# job_management                              False
# job_retired                                 False
# job_self-employed                           False
# job_services                                False
# job_student                                 False
# job_technician                              False
# job_unemployed                              False
# marital_married                              True
# marital_single                              False
# education_secondary                         False
# education_tertiary                          False
# customer_segment_High-Value                 False
# customer_segment_Middle-Market              False
# customer_segment_Retired                    False
# customer_segment_Young Professionals        False
# region_Suburban                             False
# region_Urban                                 True
# Name: 0, dtype: object
#
# Number of customers in cluster 0: 6164
#
# Cluster 1:
# age                                          61.0
# credit_default                                0.0
# income                                     2270.0
# credit_card                                   1.0
# personal_loan                                 1.0
# mortgage                                      0.0
# savings_account                               1.0
# investment_product                            0.0
# auto_loan                                     1.0
# wealth_management                             0.0
# days_since_last_transaction                   0.0
# current_balance                               0.0
# peak_month                                   12.0
# peak_month_spending                           0.0
# peak_month_frequency                         28.0
# total_transactions_3m                         0.0
# total_transactions_6m                         0.0
# total_transactions_12m                      130.0
# total_transaction_amount_3m                   0.0
# total_transaction_amount_6m                   0.0
# total_transaction_amount_12m                  0.0
# average_transaction_amount_3m                 0.0
# average_transaction_amount_6m                 0.0
# average_transaction_amount_12m                0.0
# transaction_frequency_3m                      0.0
# transaction_frequency_6m                      0.0
# transaction_frequency_12m               10.833333
# high_value_transaction_rate_3m                0.0
# high_value_transaction_rate_6m                0.0
# high_value_transaction_rate_12m          0.076923
# online_transaction_ratio_3m                   0.0
# online_transaction_ratio_6m                   0.0
# online_transaction_ratio_12m             0.298947
# has_mobile_app                                1.0
# has_web_account                               1.0
# mobile_logins_per_week                        0.0
# web_logins_per_week                           8.0
# avg_mobile_session_duration                   0.0
# avg_web_session_duration                      0.0
# job_blue-collar                             False
# job_entrepreneur                            False
# job_management                              False
# job_retired                                 False
# job_self-employed                           False
# job_services                                False
# job_student                                 False
# job_technician                              False
# job_unemployed                              False
# marital_married                              True
# marital_single                              False
# education_secondary                         False
# education_tertiary                          False
# customer_segment_High-Value                 False
# customer_segment_Middle-Market              False
# customer_segment_Retired                    False
# customer_segment_Young Professionals        False
# region_Suburban                             False
# region_Urban                                 True
# Name: 0, dtype: object
#
# Number of customers in cluster 1: 1830
#
# Cluster 2:
# age                                             48.0
# credit_default                                   0.0
# income                                        5921.0
# credit_card                                      1.0
# personal_loan                                    1.0
# mortgage                                         1.0
# savings_account                                  1.0
# investment_product                               1.0
# auto_loan                                        1.0
# wealth_management                                0.0
# days_since_last_transaction                      0.0
# current_balance                          3774.374692
# peak_month                                       1.0
# peak_month_spending                      5417.369485
# peak_month_frequency                            53.0
# total_transactions_3m                          128.0
# total_transactions_6m                          232.0
# total_transactions_12m                         507.0
# total_transaction_amount_3m                      0.0
# total_transaction_amount_6m                      0.0
# total_transaction_amount_12m            30034.787833
# average_transaction_amount_3m                    0.0
# average_transaction_amount_6m                    0.0
# average_transaction_amount_12m             56.041903
# transaction_frequency_3m                   42.666667
# transaction_frequency_6m                   38.666667
# transaction_frequency_12m                      42.25
# high_value_transaction_rate_3m              0.142857
# high_value_transaction_rate_6m                   0.0
# high_value_transaction_rate_12m             0.142857
# online_transaction_ratio_3m                      0.0
# online_transaction_ratio_6m                      0.0
# online_transaction_ratio_12m                0.447084
# has_mobile_app                                   1.0
# has_web_account                                  1.0
# mobile_logins_per_week                           7.0
# web_logins_per_week                              5.0
# avg_mobile_session_duration                      0.0
# avg_web_session_duration                         0.0
# job_blue-collar                                False
# job_entrepreneur                               False
# job_management                                  True
# job_retired                                    False
# job_self-employed                              False
# job_services                                   False
# job_student                                    False
# job_technician                                 False
# job_unemployed                                 False
# marital_married                                 True
# marital_single                                 False
# education_secondary                            False
# education_tertiary                              True
# customer_segment_High-Value                    False
# customer_segment_Middle-Market                 False
# customer_segment_Retired                       False
# customer_segment_Young Professionals           False
# region_Suburban                                False
# region_Urban                                    True
# Name: 0, dtype: object
#
# Number of customers in cluster 2: 1435
#
# For Cluster 0
#                age  credit_default       income  credit_card  personal_loan  \
# count  6164.000000     6164.000000  6164.000000  6164.000000    6164.000000
# mean     42.510221        0.035204  2986.203926     0.854640       0.626541
# std      10.294798        0.184311  1092.984143     0.352492       0.483762
# min      21.000000        0.000000     0.000000     0.000000       0.000000
# 25%      35.000000        0.000000  2241.750000     1.000000       0.000000
# 50%      43.000000        0.000000  3111.000000     1.000000       1.000000
# 75%      50.000000        0.000000  3750.250000     1.000000       1.000000
# max      77.000000        1.000000  8060.000000     1.000000       1.000000
#
#           mortgage  savings_account  investment_product    auto_loan  \
# count  6164.000000       6164.00000         6164.000000  6164.000000
# mean      0.505354          0.89974            0.293965     0.709766
# std       0.500012          0.30037            0.455613     0.453907
# min       0.000000          0.00000            0.000000     0.000000
# 25%       0.000000          1.00000            0.000000     0.000000
# 50%       1.000000          1.00000            0.000000     1.000000
# 75%       1.000000          1.00000            1.000000     1.000000
# max       1.000000          1.00000            1.000000     1.000000
#
#        wealth_management  ...  online_transaction_ratio_3m  \
# count        6164.000000  ...                  6164.000000
# mean            0.230694  ...                     0.653095
# std             0.421311  ...                     0.079636
# min             0.000000  ...                     0.000000
# 25%             0.000000  ...                     0.619970
# 50%             0.000000  ...                     0.657198
# 75%             0.000000  ...                     0.694805
# max             1.000000  ...                     0.863008
#
#        online_transaction_ratio_6m  online_transaction_ratio_12m  \
# count                  6164.000000                   6164.000000
# mean                      0.656765                      0.658585
# std                       0.065805                      0.055083
# min                       0.000000                      0.424936
# 25%                       0.621409                      0.623378
# 50%                       0.658320                      0.658003
# 75%                       0.695319                      0.695208
# max                       0.860083                      0.881280
#
#        has_mobile_app  has_web_account  mobile_logins_per_week  \
# count     6164.000000      6164.000000             6164.000000
# mean         0.858371         0.848313                6.615347
# std          0.348697         0.358747                3.391751
# min          0.000000         0.000000                0.000000
# 25%          1.000000         1.000000                5.000000
# 50%          1.000000         1.000000                7.000000
# 75%          1.000000         1.000000               10.000000
# max          1.000000         1.000000               14.000000
#
#        web_logins_per_week  avg_mobile_session_duration  \
# count          6164.000000                  6164.000000
# mean              4.854478                     3.087119
# std               2.489063                     1.917804
# min               0.000000                     0.000000
# 25%               4.000000                     1.800000
# 50%               5.000000                     3.200000
# 75%               6.000000                     4.500000
# max              10.000000                     9.200000
#
#        avg_web_session_duration  Cluster
# count               6164.000000   6164.0
# mean                   4.409620      0.0
# std                    2.628976      0.0
# min                    0.000000      0.0
# 25%                    2.800000      0.0
# 50%                    4.700000      0.0
# 75%                    6.300000      0.0
# max                   12.200000      0.0
#
# [8 rows x 40 columns]
# For Cluster 1
#                age  credit_default       income  credit_card  personal_loan  \
# count  1830.000000     1830.000000  1830.000000  1830.000000    1830.000000
# mean     60.794536        0.043169  2154.197268     0.731148       0.648087
# std      16.397781        0.203294  1319.088701     0.443484       0.477697
# min      21.000000        0.000000     0.000000     0.000000       0.000000
# 25%      50.000000        0.000000   938.000000     0.000000       0.000000
# 50%      63.000000        0.000000  2216.500000     1.000000       1.000000
# 75%      70.000000        0.000000  3005.500000     1.000000       1.000000
# max      99.000000        1.000000  9777.000000     1.000000       1.000000
#
#           mortgage  savings_account  investment_product    auto_loan  \
# count  1830.000000      1830.000000         1830.000000  1830.000000
# mean      0.444262         0.885792            0.278142     0.566667
# std       0.497019         0.318150            0.448206     0.495671
# min       0.000000         0.000000            0.000000     0.000000
# 25%       0.000000         1.000000            0.000000     0.000000
# 50%       0.000000         1.000000            0.000000     1.000000
# 75%       1.000000         1.000000            1.000000     1.000000
# max       1.000000         1.000000            1.000000     1.000000
#
#        wealth_management  ...  online_transaction_ratio_3m  \
# count        1830.000000  ...                  1830.000000
# mean            0.194536  ...                     0.467304
# std             0.395951  ...                     0.183232
# min             0.000000  ...                     0.000000
# 25%             0.000000  ...                     0.441169
# 50%             0.000000  ...                     0.502322
# 75%             0.000000  ...                     0.577433
# max             1.000000  ...                     0.785617
#
#        online_transaction_ratio_6m  online_transaction_ratio_12m  \
# count                  1830.000000                   1830.000000
# mean                      0.468937                      0.531711
# std                       0.177843                      0.087844
# min                       0.000000                      0.298947
# 25%                       0.437295                      0.465099
# 50%                       0.499993                      0.519317
# 75%                       0.575316                      0.596934
# max                       0.764070                      0.834324
#
#        has_mobile_app  has_web_account  mobile_logins_per_week  \
# count     1830.000000      1830.000000             1830.000000
# mean         0.707104         0.850820                4.780874
# std          0.455216         0.356364                3.455816
# min          0.000000         0.000000                0.000000
# 25%          0.000000         1.000000                0.000000
# 50%          1.000000         1.000000                6.000000
# 75%          1.000000         1.000000                7.000000
# max          1.000000         1.000000               13.000000
#
#        web_logins_per_week  avg_mobile_session_duration  \
# count          1830.000000                  1830.000000
# mean              6.144809                     2.714699
# std               2.945340                     2.157616
# min               0.000000                     0.000000
# 25%               5.000000                     0.000000
# 50%               7.000000                     2.900000
# 75%               8.000000                     4.500000
# max              10.000000                     8.500000
#
#        avg_web_session_duration  Cluster
# count               1830.000000   1830.0
# mean                   4.828579      1.0
# std                    2.762535      0.0
# min                    0.000000      1.0
# 25%                    3.100000      1.0
# 50%                    5.300000      1.0
# 75%                    6.800000      1.0
# max                   12.200000      1.0
#
# [8 rows x 40 columns]
# For Cluster 2
#                age  credit_default        income  credit_card  personal_loan  \
# count  1435.000000     1435.000000   1435.000000  1435.000000    1435.000000
# mean     44.070383        0.026481   7109.950523     0.905923       0.509408
# std      11.695935        0.160616   1675.877811     0.292037       0.500086
# min      21.000000        0.000000   3083.000000     0.000000       0.000000
# 25%      36.000000        0.000000   5740.000000     1.000000       0.000000
# 50%      44.000000        0.000000   7050.000000     1.000000       1.000000
# 75%      52.000000        0.000000   8545.000000     1.000000       1.000000
# max      99.000000        1.000000  14272.000000     1.000000       1.000000
#
#           mortgage  savings_account  investment_product    auto_loan  \
# count  1435.000000      1435.000000         1435.000000  1435.000000
# mean      0.633449         0.901742            0.611150     0.739373
# std       0.482030         0.297767            0.487659     0.439130
# min       0.000000         0.000000            0.000000     0.000000
# 25%       0.000000         1.000000            0.000000     0.000000
# 50%       1.000000         1.000000            1.000000     1.000000
# 75%       1.000000         1.000000            1.000000     1.000000
# max       1.000000         1.000000            1.000000     1.000000
#
#        wealth_management  ...  online_transaction_ratio_3m  \
# count        1435.000000  ...                  1435.000000
# mean            0.464808  ...                     0.686645
# std             0.498934  ...                     0.086587
# min             0.000000  ...                     0.000000
# 25%             0.000000  ...                     0.656567
# 50%             0.000000  ...                     0.697672
# 75%             1.000000  ...                     0.735211
# max             1.000000  ...                     0.846543
#
#        online_transaction_ratio_6m  online_transaction_ratio_12m  \
# count                  1435.000000                   1435.000000
# mean                      0.685623                      0.691789
# std                       0.097495                      0.063874
# min                       0.000000                      0.447084
# 25%                       0.657311                      0.657653
# 50%                       0.697301                      0.696291
# 75%                       0.737015                      0.734321
# max                       0.866541                      0.857861
#
#        has_mobile_app  has_web_account  mobile_logins_per_week  \
# count     1435.000000      1435.000000             1435.000000
# mean         0.859233         0.835540                7.059930
# std          0.347902         0.370822                3.630305
# min          0.000000         0.000000                0.000000
# 25%          1.000000         1.000000                6.000000
# 50%          1.000000         1.000000                7.000000
# 75%          1.000000         1.000000               10.000000
# max          1.000000         1.000000               14.000000
#
#        web_logins_per_week  avg_mobile_session_duration  \
# count          1435.000000                  1435.000000
# mean              4.850174                     3.215401
# std               2.610032                     1.966127
# min               0.000000                     0.000000
# 25%               4.000000                     1.900000
# 50%               5.000000                     3.400000
# 75%               6.000000                     4.600000
# max              11.000000                     8.800000
#
#        avg_web_session_duration  Cluster
# count               1435.000000   1435.0
# mean                   4.381254      2.0
# std                    2.732720      0.0
# min                    0.000000      2.0
# 25%                    2.500000      2.0
# 50%                    4.700000      2.0
# 75%                    6.400000      2.0
# max                   11.700000      2.0
#
# [8 rows x 40 columns]

# %%
# Visualise the different clusters of Age against Income

# Define colors for clusters
colors = ['blue', 'green', 'orange']

# Create figure
plt.figure(figsize=(10, 6))

# Scatter plots for each cluster with transparency
plt.scatter(cluster_0_data['income'], cluster_0_data['age'], label='Cluster 0', color=colors[0], alpha=0.5)
plt.scatter(cluster_1_data['income'], cluster_1_data['age'], label='Cluster 1', color=colors[1], alpha=0.5)
plt.scatter(cluster_2_data['income'], cluster_2_data['age'], label='Cluster 2', color=colors[2], alpha=0.5)

# Compute cluster centroids
centroids = np.array([
    [cluster_0_data['income'].mean(), cluster_0_data['age'].mean()],
    [cluster_1_data['income'].mean(), cluster_1_data['age'].mean()],
    [cluster_2_data['income'].mean(), cluster_2_data['age'].mean()]
])

# Plot centroids in respective cluster colors
plt.scatter(centroids[:, 0], centroids[:, 1], color=colors, s=200, marker='X', edgecolors='black')

# Create a custom legend handle for centroids (black color)
centroid_legend = mlines.Line2D([], [], color='black', marker='X', linestyle='None', markersize=10, label='Centroids')

# Add legend with custom centroid handle
plt.xlabel('Income')
plt.ylabel('Age')
plt.title('Income vs. Age for Each Cluster')
plt.legend(handles=[plt.Line2D([0], [0], color=color, marker='o', linestyle='None', markersize=8, label=f'Cluster {i}') for i, color in enumerate(colors)] + [centroid_legend])
plt.show()

# %% [markdown]
# # 6. BIRCH Real-time Segmentation
#
# Because Hierarchical Clustering and KMeans do not naturally support real-time segmentation, we shall explore BIRCH as a means to do so. The advantage of BIRCH as an algorithm is is able to update clusters incrementally with incoming data, making them more suitable for large datasets. We shall now test this algorithm with our dataset.

# %%
# Train BIRCH on historical data
birch = Birch(threshold=0.5, branching_factor=50, n_clusters=3) # Number of clusters are decided from hierarchical clustering results
birch.fit(scaled_data_pca)

birch_labels = birch.predict(scaled_data_pca)
print(birch_labels)
# Out:
# [1 0 0 ... 0 0 1]

# %%
# Get subclusters
subcluster_centers = birch.subcluster_centers_

# Perform hierarchical clustering on subclusters
Z = linkage(subcluster_centers, method='ward')

# Plot dendrogram
plt.figure(figsize=(10, 6))
dendrogram(Z)
plt.axhline(y=250, color='r', linestyle='--')  # Adjust threshold based on the plot
plt.title("Dendrogram of BIRCH Subclusters")
plt.xlabel("Subcluster Index")
plt.ylabel("Distance")
plt.show()

# %% [markdown]
# We can now test BIRCH's real-time segmentation capabilities by testing a singular sample of data.

# %%
# Test the real-time segmentation capabilities of BIRCH
sample_data = scaled_data_pca[900,].reshape(1, -1) # Take a random sample from the dataset or create a new sample

# Test the row
predicted_cluster = birch.predict(sample_data)
print(f"Tested row assigned to cluster: {predicted_cluster[0]}")
# Out:
# Tested row assigned to cluster: 2
