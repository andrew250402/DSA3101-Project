# %% [markdown]
# # 1. Loading Packages and Datasets

# %%
# Mounting the google drive
from google.colab import drive
import os
drive.mount('/content/drive')
os.listdir('/content/drive/MyDrive/DSA3101 Group Project/')
# Out:
# Mounted at /content/drive
# ['THE PLAYBOOK.pdf',
#  'Meeting Minutes',
#  'DSA3101 Group 2 Contributions (Video).gsheet',
#  'Customer Segmentation',
#  'Tables Explanation.gsheet',
#  'Video Script.gdoc',
#  'Project 3 Requirements.gdoc',
#  'Copy of DSA3101 Group 2 Contributions (Wiki).gsheet',
#  'Wiki.gdoc']

# %%
# Loading of packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import matplotlib.lines as mlines

from sklearn.cluster import AgglomerativeClustering, Birch
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from scipy.cluster.hierarchy import linkage, dendrogram
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
# Importing of datasets

# Specify the correct path
file_path_1= '/content/drive/My Drive/DSA3101 Group Project/Customer Segmentation/Dataset/transactions_summary.csv'
file_path_2= '/content/drive/My Drive/DSA3101 Group Project/Customer Segmentation/Dataset/digital_usage.csv'
file_path_3= '/content/drive/My Drive/DSA3101 Group Project/Customer Segmentation/Dataset/customers.csv'

# Load the datasets
Transaction = pd.read_csv(file_path_1)
Usage = pd.read_csv(file_path_2)
Customers = pd.read_csv(file_path_3)

# Check the columns of the datasets
print(Transaction.columns)
print(Usage.columns)
print(Customers.columns)
# Out:
# Index(['customer_id', 'days_since_last_transaction', 'current_balance',
#        'peak_month', 'peak_month_spending', 'peak_month_frequency',
#        'total_transactions_3m', 'total_transactions_6m',
#        'total_transactions_12m', 'total_transaction_amount_3m',
#        'total_transaction_amount_6m', 'total_transaction_amount_12m',
#        'average_transaction_amount_3m', 'average_transaction_amount_6m',
#        'average_transaction_amount_12m', 'transaction_frequency_3m',
#        'transaction_frequency_6m', 'transaction_frequency_12m',
#        'high_value_transaction_rate_3m', 'high_value_transaction_rate_6m',
#        'high_value_transaction_rate_12m', 'online_transaction_ratio_3m',
#        'online_transaction_ratio_6m', 'online_transaction_ratio_12m'],
#       dtype='object')
# Index(['customer_id', 'has_mobile_app', 'has_web_account',
#        'mobile_logins_per_week', 'web_logins_per_week',
#        'avg_mobile_session_duration', 'avg_web_session_duration',
#        'last_mobile_login', 'last_web_login'],
#       dtype='object')
# Index(['customer_id', 'age', 'job', 'marital', 'education', 'credit_default',
#        'customer_segment', 'region', 'income', 'created_at', 'credit_card',
#        'personal_loan', 'mortgage', 'savings_account', 'investment_product',
#        'auto_loan', 'wealth_management'],
#       dtype='object')

# %% [markdown]
# # 2. Cleaning and Preprocessing Datasets
#
# Now, we will clean the datasets before merging, starting off with the Usage dataset.

# %%
# Cleaning the Usage dataset
# Check for missing values
# print(Usage.isnull().sum())

# Check for 0 values in the datasets
# print((Usage == 0).sum())

# Check if Usage dataset is clean
print(Usage.describe())

# Check if last_mobile_login is null, the mobile_logins_per_week is 0, avg_mobile_session_duration is 0, and has_mobile_app is No
sum_mobile_null = Usage['last_mobile_login'].isnull().sum()
print(sum_mobile_null) # 1659
sum_mobile = 0
for _, row in Usage.iterrows():
    if row['has_mobile_app'] == 'No' and pd.isnull(row['last_mobile_login']) and row['mobile_logins_per_week'] == 0 and row['avg_mobile_session_duration'] == 0:
        sum_mobile += 1
print(sum_mobile) # 1659, the number matches as expected

# Check if last_web_login is null, the web_logins_per_week is 0, avg_web_session_duration is 0, and has_web_account is No
sum_web_null = Usage['last_web_login'].isnull().sum()
print(sum_web_null) # 1539
sum_web = 0
for _, row in Usage.iterrows():
    if row['has_web_account'] == 'No' and pd.isnull(row['last_web_login']) and row['web_logins_per_week'] == 0 and row['avg_web_session_duration'] == 0:
        sum_web += 1
print(sum_web) # 1539, the number matches as expected

# Check if last_mobile_login is null, the sum of mobile_logins_per_week is 0, avg_mobile_session_duration is 0, and has_mobile_app is No
sum_mobile = 0
for _, row in Usage.iterrows():
    if pd.isnull(row['last_mobile_login']):
        sum_mobile += row['mobile_logins_per_week'] + row['avg_mobile_session_duration'] + (1 if row['has_mobile_app'] == 'Yes' else 0)
print(sum_mobile) # 0, the number matches as expected

# Check if last_web_login is null, the sum of web_logins_per_week is 0, avg_web_session_duration is 0, and has_web_account is No
sum_web = 0
for _, row in Usage.iterrows():
    if pd.isnull(row['last_web_login']):
        sum_web += row['web_logins_per_week'] + row['avg_web_session_duration'] + (1 if row['has_web_account'] == 'Yes' else 0)
print(sum_web) # 0, the number matches as expected

# Changing Yes/No response to numerical response
columns_to_convert = ['has_mobile_app', 'has_web_account']
Usage[columns_to_convert] = Usage[columns_to_convert].replace({'Yes': 1, 'No': 0})

# Remove the last web/app log in
Usage = Usage.drop(columns=['last_mobile_login', 'last_web_login'])

print(Usage.head())
# Out:
#        customer_id  mobile_logins_per_week  web_logins_per_week  \
# count  10000.00000            10000.000000          10000.00000
# mean    5000.50000                6.458500              5.06760
# std     2886.89568                3.546764              2.63684
# min        1.00000                0.000000              0.00000
# 25%     2500.75000                5.000000              4.00000
# 50%     5000.50000                7.000000              5.00000
# 75%     7500.25000                9.000000              7.00000
# max    10000.00000               14.000000             11.00000
#
#        avg_mobile_session_duration  avg_web_session_duration
# count                 10000.000000              10000.000000
# mean                      3.030540                  4.471440
# std                       1.964464                  2.674307
# min                       0.000000                  0.000000
# 25%                       1.600000                  2.800000
# 50%                       3.200000                  4.800000
# 75%                       4.500000                  6.400000
# max                       9.200000                 12.200000
# 1659
# 1659
# 1539
# 1539
# 0.0
# 0.0
#    customer_id  has_mobile_app  has_web_account  mobile_logins_per_week  \
# 0            1               1                1                      10
# 1            2               1                1                       9
# 2            3               1                1                       6
# 3            4               1                1                       6
# 4            5               1                1                      11
#
#    web_logins_per_week  avg_mobile_session_duration  avg_web_session_duration
# 0                    5                          3.5                       6.1
# 1                    4                          4.5                       3.9
# 2                   10                          2.5                       5.4
# 3                    8                          3.0                       6.8
# 4                    6                          1.3                       1.6
# <ipython-input-4-82b0caf5de5c>:45: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Usage[columns_to_convert] = Usage[columns_to_convert].replace({'Yes': 1, 'No': 0})

# %% [markdown]
# This shows that the Usage dataset is clean. Now we will check if the Transaction dataset is clean.

# %%
# Cleaning the Transaction dataset
# Check for missing values
# print(Transaction.isnull().sum()) # 0

# Check for 0 values in the dataset
# print((Transaction == 0).sum()) # Multiple 0 values in the dataset

# Check the Statistics of the dataset
# print(Transaction.describe()) # Negative Balance, negative peak_month_spending, 0 values in the dataset

# Remove all the negative rows in the dataset
Transaction = Transaction[Transaction['current_balance'] >= 0]
Transaction = Transaction[Transaction['peak_month_spending'] >= 0]

print(Transaction.describe())

# Shape of the dataset
print(Transaction.shape) # 9940 rows and 24 columns

# Find the rows where average_transaction_amount_12m is 0
zero_avg_transaction = Transaction[Transaction['average_transaction_amount_12m'] == 0]
# Show in table format
display(zero_avg_transaction)
# Out:
#         customer_id  days_since_last_transaction  current_balance  \
# count   9940.000000                  9940.000000      9940.000000
# mean    5000.387827                    23.904527      6835.469185
# std     2885.720548                    36.112473      4657.206812
# min        1.000000                     0.000000         0.000000
# 25%     2501.750000                     5.000000      3670.094710
# 50%     4999.500000                    14.000000      5884.822167
# 75%     7499.250000                    26.000000      8863.982631
# max    10000.000000                   200.000000     39748.029652
#
#         peak_month  peak_month_spending  peak_month_frequency  \
# count  9940.000000          9940.000000           9940.000000
# mean      6.613380         16752.335891             43.036519
# std       3.579621         17618.017033             11.596799
# min       1.000000             0.000000             12.000000
# 25%       3.000000          6019.524591             37.000000
# 50%       7.000000         11807.830133             44.000000
# 75%      10.000000         21356.305352             51.000000
# max      12.000000        282205.767182             77.000000
#
#        total_transactions_3m  total_transactions_6m  total_transactions_12m  \
# count            9940.000000            9940.000000             9940.000000
# mean               98.061771             196.416499              401.161167
# std                34.219191              66.956912              101.883694
# min                 0.000000               0.000000              104.000000
# 25%                80.000000             161.000000              353.000000
# 50%               100.000000             200.000000              413.000000
# 75%               120.000000             239.000000              464.000000
# max               220.000000             472.000000              681.000000
#
#        total_transaction_amount_3m  ...  average_transaction_amount_12m  \
# count                  9940.000000  ...                     9940.000000
# mean                  18346.922341  ...                      192.318259
# std                   15149.068568  ...                      166.745994
# min                       0.000000  ...                        0.000000
# 25%                    7951.435827  ...                       86.223191
# 50%                   15322.038311  ...                      149.453467
# 75%                   23300.934875  ...                      246.037271
# max                  113808.191909  ...                     2779.916745
#
#        transaction_frequency_3m  transaction_frequency_6m  \
# count               9940.000000               9940.000000
# mean                  32.687257                 32.736083
# std                   11.406397                 11.159485
# min                    0.000000                  0.000000
# 25%                   26.666667                 26.833333
# 50%                   33.333333                 33.333333
# 75%                   40.000000                 39.833333
# max                   73.333333                 78.666667
#
#        transaction_frequency_12m  high_value_transaction_rate_3m  \
# count                9940.000000                     9940.000000
# mean                   33.430097                        0.091223
# std                     8.490308                        0.044714
# min                     8.666667                        0.000000
# 25%                    29.416667                        0.060241
# 50%                    34.416667                        0.089552
# 75%                    38.666667                        0.120000
# max                    56.750000                        0.294118
#
#        high_value_transaction_rate_6m  high_value_transaction_rate_12m  \
# count                     9940.000000                      9940.000000
# mean                         0.091793                         0.093459
# std                          0.039144                         0.033226
# min                          0.000000                         0.012903
# 25%                          0.064706                         0.068060
# 50%                          0.089623                         0.090909
# 75%                          0.117931                         0.115385
# max                          0.239865                         0.240991
#
#        online_transaction_ratio_3m  online_transaction_ratio_6m  \
# count                  9940.000000                  9940.000000
# mean                      0.625378                     0.627793
# std                       0.132259                     0.127022
# min                       0.000000                     0.000000
# 25%                       0.596206                     0.598601
# 50%                       0.651625                     0.652030
# 75%                       0.696704                     0.697260
# max                       0.864804                     0.866541
#
#        online_transaction_ratio_12m
# count                   9940.000000
# mean                       0.641855
# std                        0.083767
# min                        0.298947
# 25%                        0.603974
# 50%                        0.653523
# 75%                        0.697740
# max                        0.881280
#
# [8 rows x 24 columns]
# (9940, 24)
#       customer_id  days_since_last_transaction  current_balance  peak_month  \
# 7120         7121                          130              0.0           9
# 8160         8161                            4              0.0           7
#
#       peak_month_spending  peak_month_frequency  total_transactions_3m  \
# 7120                  0.0                    16                      0
# 8160                  0.0                    35                     88
#
#       total_transactions_6m  total_transactions_12m  \
# 7120                    112                     162
# 8160                    171                     320
#
#       total_transaction_amount_3m  ...  average_transaction_amount_12m  \
# 7120                          0.0  ...                             0.0
# 8160                          0.0  ...                             0.0
#
#       transaction_frequency_3m  transaction_frequency_6m  \
# 7120                  0.000000                 18.666667
# 8160                 29.333333                 28.500000
#
#       transaction_frequency_12m  high_value_transaction_rate_3m  \
# 7120                  13.500000                        0.000000
# 8160                  26.666667                        0.034091
#
#       high_value_transaction_rate_6m  high_value_transaction_rate_12m  \
# 7120                        0.098214                         0.049383
# 8160                        0.046784                         0.037500
#
#       online_transaction_ratio_3m  online_transaction_ratio_6m  \
# 7120                     0.000000                     0.470890
# 8160                     0.726451                     0.672533
#
#       online_transaction_ratio_12m
# 7120                      0.510629
# 8160                      0.628687
#
# [2 rows x 24 columns]

# %% [markdown]
# From the above cleaning, we have removed the negative values by eliminating the entire row. We kept the 0 values since there could be a possibility (low) that current balance is 0 and therefore the rest of the transaction information is 0 as well.

# %% [markdown]
# We will now clean the Customer dataset and experiment customer segmentation with just the Customer dataset alone. This is for building model for New customer where we only have the customers' profile data.

# %%
# Load data
customer_data = pd.read_csv(file_path_3)

# Data cleaning and processing
columns_to_convert = ['credit_default', 'credit_card', 'personal_loan', 'mortgage', 'savings_account', 'investment_product', 'auto_loan', 'wealth_management']
customer_data[columns_to_convert] = customer_data[columns_to_convert].replace({'yes': 1, 'no': 0})
customer_data = customer_data[customer_data['income'] >= 0] # Filter out entries with negative income
customer_data = customer_data[customer_data['age'] >= 21] # Filter out non-adults
customer_data = customer_data[customer_data['created_at'] < '2025-03-01'] # Filter out erroneous entries
customer_data = customer_data.drop(columns=['created_at']) # Remove column
customer_data = customer_data.drop(columns=['customer_segment']) # Remove column
customer_data_original = customer_data.copy() # To be used for merging
customer_data = customer_data.drop(columns=['customer_id']) # Remove column

# Show first few entries
customer_data.head()
# Out:
# <ipython-input-11-4ef13a3c569b>:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   customer_data[columns_to_convert] = customer_data[columns_to_convert].replace({'yes': 1, 'no': 0})
#    age          job   marital  education  credit_default region  income  \
# 0   38  blue-collar   married  secondary               0  Urban    2603
# 2   73     services  divorced  secondary               0  Urban    3130
# 3   87      retired   married    primary               0  Urban    2401
# 5   46   technician   married   tertiary               0  Urban    3355
# 6   70        admin   married   tertiary               0  Urban    4918
#
#    credit_card  personal_loan  mortgage  savings_account  investment_product  \
# 0            1              1         1                1                   1
# 2            1              0         0                0                   1
# 3            1              1         0                1                   0
# 5            1              1         0                1                   0
# 6            1              1         1                1                   0
#
#    auto_loan  wealth_management
# 0          1                  1
# 2          1                  0
# 3          0                  0
# 5          1                  1
# 6          1                  0

# %% [markdown]
# # 3. Feature Engineering
#
# To handle categorical variables, we first use one-hot encoding to convert them to numerical variables. We then standardise our data using StandardScaler to ensure all feature contribute equally to distance metrics.

# %%
# Create one hot encoding for categorical variables
customer_data_encoded = pd.get_dummies(customer_data)

# Standardise the data
data_scaler = StandardScaler()
scaled_data = data_scaler.fit_transform(customer_data_encoded)
scaled_data.shape
# Out:
# (9429, 29)

# %% [markdown]
# Due to the high number of columns present in the dataset, we shall first use PCA for dimensionality reduction. We then create a Scree Plot to decide how many components we would like to keep in order to retain a high cumulative explained variance of about 95%.

# %%
# Create a Scree Plot to decide the number of components to use
pca = PCA().fit(scaled_data)

plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Scree Plot')
plt.grid()
plt.show()

# %% [markdown]
# # 4. Hierarchical Clustering

# %%
pca = PCA(n_components=22)  # Reduce to 22 dimensions (chosen from Scree Plot)
scaled_data_pca = pca.fit_transform(scaled_data)  # Transform data

# Compute hierarchical clustering
linkage_matrix = linkage(scaled_data_pca, method='ward')  # Ward's method for variance minimisation

# Plot dendrogram
plt.figure(figsize=(10, 5))
dendrogram(linkage_matrix)
plt.axhline(y=150, color='r', linestyle='--')  # Adjust threshold based on the plot
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Samples')
plt.ylabel('Distance')
plt.show()

# %%
# Assign cluster labels (decide number of clusters from dendrogram)
n_clusters = 4
cluster_labels = AgglomerativeClustering(n_clusters=n_clusters, linkage='ward').fit_predict(scaled_data_pca)

print(f"Cluster assignments: {np.unique(cluster_labels, return_counts=True)}")
cluster_labels
# Out:
# Cluster assignments: (array([0, 1, 2, 3]), array([1810, 6395,  756,  468]))
# array([1, 1, 3, ..., 2, 1, 1])

# %%
# Merge cluster labels with the customer dataset
customer_data_with_labels = customer_data
customer_data_with_labels['cluster'] = cluster_labels

# Count the numbers in each cluster
customer_data_with_labels['cluster'].value_counts()
# Out:
# cluster
# 1    6395
# 0    1810
# 2     756
# 3     468
# Name: count, dtype: int64

# %%
# Find the most common traits of each cluster, and count of each traits
unique_traits = {}
for cluster_id in range(n_clusters):
    cluster_data = customer_data_with_labels[customer_data_with_labels['cluster'] == cluster_id]
    unique_traits[cluster_id] = cluster_data.drop(columns=['cluster']).mode().iloc[0]
    print(f"Cluster {cluster_id}:")
    print(unique_traits[cluster_id])
    print()
    print(f"Number of customers in cluster {cluster_id}: {len(cluster_data)}")
    print()
# Out:
# Cluster 0:
# age                           43
# job                   management
# marital                  married
# education               tertiary
# credit_default                 0
# region                     Urban
# income                      6753
# credit_card                    1
# personal_loan                  1
# mortgage                       1
# savings_account                1
# investment_product             1
# auto_loan                      1
# wealth_management              0
# Name: 0, dtype: object
#
# Number of customers in cluster 0: 1810
#
# Cluster 1:
# age                          46.0
# job                   blue-collar
# marital                   married
# education               secondary
# credit_default                0.0
# region                      Urban
# income                       2628
# credit_card                   1.0
# personal_loan                 1.0
# mortgage                      1.0
# savings_account               1.0
# investment_product            0.0
# auto_loan                     1.0
# wealth_management             0.0
# Name: 0, dtype: object
#
# Number of customers in cluster 1: 6395
#
# Cluster 2:
# age                         23.0
# job                   unemployed
# marital                  married
# education               tertiary
# credit_default               0.0
# region                     Urban
# income                        69
# credit_card                  1.0
# personal_loan                1.0
# mortgage                     0.0
# savings_account              1.0
# investment_product           0.0
# auto_loan                    0.0
# wealth_management            0.0
# Name: 0, dtype: object
#
# Number of customers in cluster 2: 756
#
# Cluster 3:
# age                          87
# job                     retired
# marital                 married
# education             secondary
# credit_default                0
# region                    Urban
# income                     2270
# credit_card                   1
# personal_loan                 1
# mortgage                      0
# savings_account               1
# investment_product            0
# auto_loan                     0
# wealth_management             0
# Name: 0, dtype: object
#
# Number of customers in cluster 3: 468

# %% [markdown]
# As we can see, cluster 0 is the high-valued, cluster 1 is middle income, cluster 2 is young adults/interns, and cluster 3 is retirees

# %%
# Each cluster statistical distributions

# For cluster 0
cluster_0_data = customer_data_with_labels[customer_data_with_labels['cluster'] == 0]
print('For Cluster 0')
print(cluster_0_data.describe()) # Mean income of $6269

# For cluster 1
cluster_1_data = customer_data_with_labels[customer_data_with_labels['cluster'] == 1]
print('For Cluster 1')
print(cluster_1_data.describe()) # Mean income of $3078

# For cluster 2
cluster_2_data = customer_data_with_labels[customer_data_with_labels['cluster'] == 2]
print('For Cluster 2')
print(cluster_2_data.describe()) # Mean income of $589

# For cluster 3
cluster_3_data = customer_data_with_labels[customer_data_with_labels['cluster'] == 3]
print('For Cluster 3')
print(cluster_3_data.describe()) # Mean income of $2289
# Out:
# For Cluster 0
#                age  credit_default        income  credit_card  personal_loan  \
# count  1810.000000          1810.0   1810.000000  1810.000000    1810.000000
# mean     45.136464             0.0   6269.449171     0.889503       0.539779
# std      12.077813             0.0   2180.200156     0.313595       0.498553
# min      21.000000             0.0   1519.000000     0.000000       0.000000
# 25%      37.000000             0.0   4809.250000     1.000000       0.000000
# 50%      44.000000             0.0   6264.500000     1.000000       1.000000
# 75%      53.000000             0.0   8049.250000     1.000000       1.000000
# max      99.000000             0.0  14272.000000     1.000000       1.000000
#
#           mortgage  savings_account  investment_product    auto_loan  \
# count  1810.000000      1810.000000         1810.000000  1810.000000
# mean      0.607182         0.906630            0.562431     0.729282
# std       0.488512         0.291031            0.496224     0.444454
# min       0.000000         0.000000            0.000000     0.000000
# 25%       0.000000         1.000000            0.000000     0.000000
# 50%       1.000000         1.000000            1.000000     1.000000
# 75%       1.000000         1.000000            1.000000     1.000000
# max       1.000000         1.000000            1.000000     1.000000
#
#        wealth_management  cluster
# count        1810.000000   1810.0
# mean            0.426519      0.0
# std             0.494708      0.0
# min             0.000000      0.0
# 25%             0.000000      0.0
# 50%             0.000000      0.0
# 75%             1.000000      0.0
# max             1.000000      0.0
# For Cluster 1
#                age  credit_default       income  credit_card  personal_loan  \
# count  6395.000000     6395.000000  6395.000000  6395.000000    6395.000000
# mean     45.679124        0.051134  3078.434246     0.863331       0.618921
# std      11.825956        0.220288  1065.748703     0.343525       0.485690
# min      21.000000        0.000000    40.000000     0.000000       0.000000
# 25%      37.000000        0.000000  2375.000000     1.000000       0.000000
# 50%      45.000000        0.000000  3143.000000     1.000000       1.000000
# 75%      53.000000        0.000000  3774.000000     1.000000       1.000000
# max      99.000000        1.000000  9962.000000     1.000000       1.000000
#
#           mortgage  savings_account  investment_product    auto_loan  \
# count  6395.000000      6395.000000         6395.000000  6395.000000
# mean      0.502580         0.904300            0.288507     0.715246
# std       0.500032         0.294202            0.453103     0.451332
# min       0.000000         0.000000            0.000000     0.000000
# 25%       0.000000         1.000000            0.000000     0.000000
# 50%       1.000000         1.000000            0.000000     1.000000
# 75%       1.000000         1.000000            1.000000     1.000000
# max       1.000000         1.000000            1.000000     1.000000
#
#        wealth_management  cluster
# count        6395.000000   6395.0
# mean            0.220172      1.0
# std             0.414395      0.0
# min             0.000000      1.0
# 25%             0.000000      1.0
# 50%             0.000000      1.0
# 75%             0.000000      1.0
# max             1.000000      1.0
# For Cluster 2
#               age  credit_default       income  credit_card  personal_loan  \
# count  756.000000      756.000000   756.000000   756.000000     756.000000
# mean    36.407407        0.009259   589.992063     0.591270       0.714286
# std     14.282603        0.095842   382.902311     0.491925       0.452053
# min     21.000000        0.000000     0.000000     0.000000       0.000000
# 25%     24.000000        0.000000   287.500000     0.000000       0.000000
# 50%     33.000000        0.000000   550.500000     1.000000       1.000000
# 75%     47.250000        0.000000   848.000000     1.000000       1.000000
# max     99.000000        1.000000  3717.000000     1.000000       1.000000
#
#          mortgage  savings_account  investment_product   auto_loan  \
# count  756.000000       756.000000          756.000000  756.000000
# mean     0.432540         0.802910            0.280423    0.484127
# std      0.495756         0.398064            0.449503    0.500079
# min      0.000000         0.000000            0.000000    0.000000
# 25%      0.000000         1.000000            0.000000    0.000000
# 50%      0.000000         1.000000            0.000000    0.000000
# 75%      1.000000         1.000000            1.000000    1.000000
# max      1.000000         1.000000            1.000000    1.000000
#
#        wealth_management  cluster
# count         756.000000    756.0
# mean            0.244709      2.0
# std             0.430199      0.0
# min             0.000000      2.0
# 25%             0.000000      2.0
# 50%             0.000000      2.0
# 75%             0.000000      2.0
# max             1.000000      2.0
# For Cluster 3
#               age  credit_default       income  credit_card  personal_loan  \
# count  468.000000           468.0   468.000000   468.000000     468.000000
# mean    75.190171             0.0  2289.737179     0.700855       0.649573
# std      9.211769             0.0   540.501188     0.458374       0.477614
# min     60.000000             0.0  1514.000000     0.000000       0.000000
# 25%     67.000000             0.0  1916.500000     0.000000       0.000000
# 50%     76.000000             0.0  2257.500000     1.000000       1.000000
# 75%     83.000000             0.0  2640.000000     1.000000       1.000000
# max     98.000000             0.0  7722.000000     1.000000       1.000000
#
#          mortgage  savings_account  investment_product   auto_loan  \
# count  468.000000       468.000000          468.000000  468.000000
# mean     0.420940         0.918803            0.262821    0.455128
# std      0.494238         0.273429            0.440637    0.498515
# min      0.000000         0.000000            0.000000    0.000000
# 25%      0.000000         1.000000            0.000000    0.000000
# 50%      0.000000         1.000000            0.000000    0.000000
# 75%      1.000000         1.000000            1.000000    1.000000
# max      1.000000         1.000000            1.000000    1.000000
#
#        wealth_management  cluster
# count          468.00000    468.0
# mean             0.17094      3.0
# std              0.37686      0.0
# min              0.00000      3.0
# 25%              0.00000      3.0
# 50%              0.00000      3.0
# 75%              0.00000      3.0
# max              1.00000      3.0

# %%
# Visualise the different clusters of Age against Income

# Define colors for clusters
colors = ['blue', 'green', 'orange', 'purple']

# Create figure
plt.figure(figsize=(10, 6))

# Scatter plots for each cluster with transparency
plt.scatter(cluster_0_data['income'], cluster_0_data['age'], label='Cluster 0', color=colors[0], alpha=0.5)
plt.scatter(cluster_1_data['income'], cluster_1_data['age'], label='Cluster 1', color=colors[1], alpha=0.5)
plt.scatter(cluster_2_data['income'], cluster_2_data['age'], label='Cluster 2', color=colors[2], alpha=0.5)
plt.scatter(cluster_3_data['income'], cluster_3_data['age'], label='Cluster 3', color=colors[3], alpha=0.5)

# Compute cluster centroids
centroids = np.array([
    [cluster_0_data['income'].mean(), cluster_0_data['age'].mean()],
    [cluster_1_data['income'].mean(), cluster_1_data['age'].mean()],
    [cluster_2_data['income'].mean(), cluster_2_data['age'].mean()],
    [cluster_3_data['income'].mean(), cluster_3_data['age'].mean()]
])

# Plot centroids in respective cluster colors
plt.scatter(centroids[:, 0], centroids[:, 1], color=colors, s=200, marker='X', edgecolors='black')

# Create a custom legend handle for centroids (black color)
centroid_legend = mlines.Line2D([], [], color='black', marker='X', linestyle='None', markersize=10, label='Centroids')

# Add legend with custom centroid handle
plt.xlabel('Income')
plt.ylabel('Age')
plt.title('Income vs. Age for Each Cluster')
plt.legend(handles=[plt.Line2D([0], [0], color=color, marker='o', linestyle='None', markersize=8, label=f'Cluster {i}') for i, color in enumerate(colors)] + [centroid_legend])
plt.show()

# %% [markdown]
# This shows that the hierarchical clustering does a good job in clustering the customers into 4 different segments.

# %% [markdown]
# # 5. KMeans Clustering

# %%
# Find the optimal number of clusters for KMeans
silhouette_scores = []
cluster_range = range(2, 10)  # Start from 3 clusters to max 9 clusters

for n_clusters in cluster_range:
    kmeans = KMeans(n_clusters=n_clusters, random_state=42, n_init=10)
    cluster_labels = kmeans.fit_predict(scaled_data_pca)

    # Calculate Silhouette Score
    silhouette_avg = silhouette_score(scaled_data_pca, cluster_labels)
    silhouette_scores.append(silhouette_avg)

# Plot Silhouette Score
plt.subplot(1, 2, 2)
plt.plot(cluster_range, silhouette_scores, marker='o', color='r')
plt.title('Silhouette Score')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.tight_layout()
plt.show()

# %%
# K-means Clustering
# Apply K-Means with chosen K (K=4)
kmeans = KMeans(n_clusters=4, random_state=42, n_init=10)
cluster_labels = kmeans.fit_predict(scaled_data_pca)

# Add cluster labels to the dataset
customer_data_with_labels_kmean = customer_data
customer_data_with_labels_kmean['Cluster'] = cluster_labels

# Find the most common traits of each cluster, and count of each traits
unique_traits = {}
n_clusters = 4
for cluster_id in range(n_clusters):
    cluster_data = customer_data_with_labels_kmean[customer_data_with_labels_kmean['Cluster'] == cluster_id]
    unique_traits[cluster_id] = cluster_data.drop(columns=['Cluster']).mode().iloc[0]
    print(f"Cluster {cluster_id}:")
    print(unique_traits[cluster_id])
    print()
    print(f"Number of customers in cluster {cluster_id}: {len(cluster_data)}")
    print()

# Each cluster statistical distributions
# For cluster 0
cluster_0_data = customer_data_with_labels_kmean[customer_data_with_labels_kmean['Cluster'] == 0]
print('For Cluster 0')
print(cluster_0_data.describe()) # Mean income of $2676

# For cluster 1
cluster_1_data = customer_data_with_labels_kmean[customer_data_with_labels_kmean['Cluster'] == 1]
print('For Cluster 1')
print(cluster_1_data.describe()) # Mean income of $2957

# For cluster 2
cluster_2_data = customer_data_with_labels_kmean[customer_data_with_labels_kmean['Cluster'] == 2]
print('For Cluster 2')
print(cluster_2_data.describe()) # Mean income of $2735

# For cluster 3
cluster_3_data = customer_data_with_labels_kmean[customer_data_with_labels_kmean['Cluster'] == 3]
print('For Cluster 3')
print(cluster_3_data.describe()) # Mean income of $7309
# Out:
# Cluster 0:
# age                          25.0
# job                   blue-collar
# marital                    single
# education               secondary
# credit_default                0.0
# region                      Urban
# income                       1224
# credit_card                   1.0
# personal_loan                 1.0
# mortgage                      0.0
# savings_account               1.0
# investment_product            0.0
# auto_loan                     1.0
# wealth_management             0.0
# cluster                       1.0
# Name: 0, dtype: object
#
# Number of customers in cluster 0: 2035
#
# Cluster 1:
# age                          47.0
# job                   blue-collar
# marital                   married
# education               secondary
# credit_default                0.0
# region                      Urban
# income                       3125
# credit_card                   1.0
# personal_loan                 1.0
# mortgage                      1.0
# savings_account               1.0
# investment_product            0.0
# auto_loan                     1.0
# wealth_management             0.0
# cluster                       1.0
# Name: 0, dtype: object
#
# Number of customers in cluster 1: 4642
#
# Cluster 2:
# age                        61.0
# job                     retired
# marital                divorced
# education             secondary
# credit_default              0.0
# region                    Urban
# income                     2270
# credit_card                 1.0
# personal_loan               1.0
# mortgage                    0.0
# savings_account             1.0
# investment_product          0.0
# auto_loan                   1.0
# wealth_management           0.0
# cluster                     1.0
# Name: 0, dtype: object
#
# Number of customers in cluster 2: 1473
#
# Cluster 3:
# age                           38
# job                   management
# marital                  married
# education               tertiary
# credit_default                 0
# region                     Urban
# income                      6753
# credit_card                    1
# personal_loan                  1
# mortgage                       1
# savings_account                1
# investment_product             1
# auto_loan                      1
# wealth_management              1
# cluster                        0
# Name: 0, dtype: object
#
# Number of customers in cluster 3: 1279
#
# For Cluster 0
#                age  credit_default       income  credit_card  personal_loan  \
# count  2035.000000     2035.000000  2035.000000  2035.000000    2035.000000
# mean     38.344963        0.038821  2676.514005     0.786732       0.624079
# std      12.696438        0.193215  1408.413595     0.409716       0.484479
# min      21.000000        0.000000     0.000000     0.000000       0.000000
# 25%      26.000000        0.000000  1472.500000     1.000000       0.000000
# 50%      38.000000        0.000000  2878.000000     1.000000       1.000000
# 75%      48.000000        0.000000  3694.000000     1.000000       1.000000
# max      80.000000        1.000000  8060.000000     1.000000       1.000000
#
#           mortgage  savings_account  investment_product    auto_loan  \
# count  2035.000000      2035.000000         2035.000000  2035.000000
# mean      0.367076         0.884521            0.294349     0.653563
# std       0.482126         0.319678            0.455862     0.475951
# min       0.000000         0.000000            0.000000     0.000000
# 25%       0.000000         1.000000            0.000000     0.000000
# 50%       0.000000         1.000000            0.000000     1.000000
# 75%       1.000000         1.000000            1.000000     1.000000
# max       1.000000         1.000000            1.000000     1.000000
#
#        wealth_management      cluster  Cluster
# count        2035.000000  2035.000000   2035.0
# mean            0.237346     1.116953      0.0
# std             0.425561     0.519135      0.0
# min             0.000000     0.000000      0.0
# 25%             0.000000     1.000000      0.0
# 50%             0.000000     1.000000      0.0
# 75%             0.000000     1.000000      0.0
# max             1.000000     2.000000      0.0
# For Cluster 1
#                age  credit_default       income  credit_card  personal_loan  \
# count  4642.000000     4642.000000  4642.000000  4642.000000    4642.000000
# mean     46.017019        0.032960  2957.120638     0.860405       0.629901
# std      10.346587        0.178551  1190.601710     0.346604       0.482883
# min      21.000000        0.000000     1.000000     0.000000       0.000000
# 25%      38.000000        0.000000  2150.500000     1.000000       0.000000
# 50%      46.000000        0.000000  3103.500000     1.000000       1.000000
# 75%      53.000000        0.000000  3775.500000     1.000000       1.000000
# max      99.000000        1.000000  8517.000000     1.000000       1.000000
#
#           mortgage  savings_account  investment_product    auto_loan  \
# count  4642.000000      4642.000000         4642.000000  4642.000000
# mean      0.584877         0.897458            0.302671     0.716932
# std       0.492796         0.303392            0.459464     0.450538
# min       0.000000         0.000000            0.000000     0.000000
# 25%       0.000000         1.000000            0.000000     0.000000
# 50%       1.000000         1.000000            0.000000     1.000000
# 75%       1.000000         1.000000            1.000000     1.000000
# max       1.000000         1.000000            1.000000     1.000000
#
#        wealth_management      cluster  Cluster
# count        4642.000000  4642.000000   4642.0
# mean            0.221025     0.990521      1.0
# std             0.414982     0.361228      0.0
# min             0.000000     0.000000      1.0
# 25%             0.000000     1.000000      1.0
# 50%             0.000000     1.000000      1.0
# 75%             0.000000     1.000000      1.0
# max             1.000000     2.000000      1.0
# For Cluster 2
#                age  credit_default       income  credit_card  personal_loan  \
# count  1473.000000      1473.00000  1473.000000  1473.000000    1473.000000
# mean     59.099117         0.04888  2735.632722     0.778683       0.628649
# std      17.395408         0.21569  1117.107921     0.415274       0.483330
# min      21.000000         0.00000     0.000000     0.000000       0.000000
# 25%      45.000000         0.00000  1970.000000     1.000000       0.000000
# 50%      61.000000         0.00000  2675.000000     1.000000       1.000000
# 75%      71.000000         0.00000  3450.000000     1.000000       1.000000
# max      99.000000         1.00000  9605.000000     1.000000       1.000000
#
#           mortgage  savings_account  investment_product    auto_loan  \
# count  1473.000000      1473.000000         1473.000000  1473.000000
# mean      0.377461         0.911066            0.268160     0.593347
# std       0.484916         0.284745            0.443152     0.491376
# min       0.000000         0.000000            0.000000     0.000000
# 25%       0.000000         1.000000            0.000000     0.000000
# 50%       0.000000         1.000000            0.000000     1.000000
# 75%       1.000000         1.000000            1.000000     1.000000
# max       1.000000         1.000000            1.000000     1.000000
#
#        wealth_management      cluster  Cluster
# count        1473.000000  1473.000000   1473.0
# mean            0.194840     1.632722      2.0
# std             0.396212     0.982974      0.0
# min             0.000000     0.000000      2.0
# 25%             0.000000     1.000000      2.0
# 50%             0.000000     1.000000      2.0
# 75%             0.000000     3.000000      2.0
# max             1.000000     3.000000      2.0
# For Cluster 3
#                age  credit_default        income  credit_card  personal_loan  \
# count  1279.000000     1279.000000   1279.000000  1279.000000    1279.000000
# mean     45.216575        0.023456   7309.362002     0.910086       0.515246
# std      11.840456        0.151405   1677.335170     0.286170       0.499963
# min      21.000000        0.000000   1596.000000     0.000000       0.000000
# 25%      37.000000        0.000000   6102.500000     1.000000       0.000000
# 50%      44.000000        0.000000   7357.000000     1.000000       1.000000
# 75%      53.000000        0.000000   8678.500000     1.000000       1.000000
# max      99.000000        1.000000  14272.000000     1.000000       1.000000
#
#           mortgage  savings_account  investment_product    auto_loan  \
# count  1279.000000      1279.000000         1279.000000  1279.000000
# mean      0.640344         0.901486            0.624707     0.735731
# std       0.480087         0.298126            0.484388     0.441116
# min       0.000000         0.000000            0.000000     0.000000
# 25%       0.000000         1.000000            0.000000     0.000000
# 50%       1.000000         1.000000            1.000000     1.000000
# 75%       1.000000         1.000000            1.000000     1.000000
# max       1.000000         1.000000            1.000000     1.000000
#
#        wealth_management      cluster  Cluster
# count        1279.000000  1279.000000   1279.0
# mean            0.507428     0.027365      3.0
# std             0.500140     0.163209      0.0
# min             0.000000     0.000000      3.0
# 25%             0.000000     0.000000      3.0
# 50%             1.000000     0.000000      3.0
# 75%             1.000000     0.000000      3.0
# max             1.000000     1.000000      3.0

# %%
# Visualise the different clusters of Age against Income

# Define colors for clusters
colors = ['blue', 'green', 'orange', 'purple']

# Create figure
plt.figure(figsize=(10, 6))

# Scatter plots for each cluster with transparency
plt.scatter(cluster_0_data['income'], cluster_0_data['age'], label='Cluster 0', color=colors[0], alpha=0.5)
plt.scatter(cluster_1_data['income'], cluster_1_data['age'], label='Cluster 1', color=colors[1], alpha=0.5)
plt.scatter(cluster_2_data['income'], cluster_2_data['age'], label='Cluster 2', color=colors[2], alpha=0.5)
plt.scatter(cluster_3_data['income'], cluster_3_data['age'], label='Cluster 3', color=colors[3], alpha=0.5)

# Compute cluster centroids
centroids = np.array([
    [cluster_0_data['income'].mean(), cluster_0_data['age'].mean()],
    [cluster_1_data['income'].mean(), cluster_1_data['age'].mean()],
    [cluster_2_data['income'].mean(), cluster_2_data['age'].mean()],
    [cluster_3_data['income'].mean(), cluster_3_data['age'].mean()]
])

# Plot centroids in respective cluster colors
plt.scatter(centroids[:, 0], centroids[:, 1], color=colors, s=200, marker='X', edgecolors='black')

# Create a custom legend handle for centroids (black color)
centroid_legend = mlines.Line2D([], [], color='black', marker='X', linestyle='None', markersize=10, label='Centroids')

# Add legend with custom centroid handle
plt.xlabel('Income')
plt.ylabel('Age')
plt.title('Income vs. Age for Each Cluster')
plt.legend(handles=[plt.Line2D([0], [0], color=color, marker='o', linestyle='None', markersize=8, label=f'Cluster {i}') for i, color in enumerate(colors)] + [centroid_legend])
plt.show()

# %% [markdown]
# ### Conclusion for New Customers Segments
# The segments for KMeans are not as clear and interpretable compared to hierarchical clustering. As such, we wull adopt the hierarchical clustering model to segment new customers.

# %% [markdown]
# # 6. Merging the datasets and implementing both KMeans and Hierarchical Clustering
# We will now merge the customer dataset with transaction and usage dataset and implement the same 2 models as above for Existing Customers as digital usage and transaction history data are readily available.

# %%
# Merge the datasets
df = pd.merge(customer_data_original, Transaction, on='customer_id', how='inner')
df = pd.merge(df, Usage, on='customer_id', how='inner')

# Check the shape of the merge dataset
print(df.shape) # 9429 rows
print(df.columns)
# Out:
# (9429, 44)
# Index(['customer_id', 'age', 'job', 'marital', 'education', 'credit_default',
#        'region', 'income', 'credit_card', 'personal_loan', 'mortgage',
#        'savings_account', 'investment_product', 'auto_loan',
#        'wealth_management', 'days_since_last_transaction', 'current_balance',
#        'peak_month', 'peak_month_spending', 'peak_month_frequency',
#        'total_transactions_3m', 'total_transactions_6m',
#        'total_transactions_12m', 'total_transaction_amount_3m',
#        'total_transaction_amount_6m', 'total_transaction_amount_12m',
#        'average_transaction_amount_3m', 'average_transaction_amount_6m',
#        'average_transaction_amount_12m', 'transaction_frequency_3m',
#        'transaction_frequency_6m', 'transaction_frequency_12m',
#        'high_value_transaction_rate_3m', 'high_value_transaction_rate_6m',
#        'high_value_transaction_rate_12m', 'online_transaction_ratio_3m',
#        'online_transaction_ratio_6m', 'online_transaction_ratio_12m',
#        'has_mobile_app', 'has_web_account', 'mobile_logins_per_week',
#        'web_logins_per_week', 'avg_mobile_session_duration',
#        'avg_web_session_duration'],
#       dtype='object')

# %%
# Remove 'customer_id' column
df = df.drop('customer_id', axis=1)

# Identify categorical columns
categorical_cols = df.select_dtypes(include=['object']).columns

# Apply One-Hot Encoding
df_encoded = pd.get_dummies(df, columns=categorical_cols, drop_first=True)
print(df_encoded.head())

# Standardise the data
data_scaler = StandardScaler()
scaled_data = data_scaler.fit_transform(df_encoded)
scaled_data.shape # 9429 Rows
# Out:
#    age  credit_default  income  credit_card  personal_loan  mortgage  \
# 0   38               0    2603            1              1         1
# 1   73               0    3130            1              0         0
# 2   87               0    2401            1              1         0
# 3   46               0    3355            1              1         0
# 4   70               0    4918            1              1         1
#
#    savings_account  investment_product  auto_loan  wealth_management  ...  \
# 0                1                   1          1                  1  ...
# 1                0                   1          1                  0  ...
# 2                1                   0          0                  0  ...
# 3                1                   0          1                  1  ...
# 4                1                   0          1                  0  ...
#
#    job_services  job_student  job_technician  job_unemployed  marital_married  \
# 0         False        False           False           False             True
# 1          True        False           False           False            False
# 2         False        False           False           False             True
# 3         False        False            True           False             True
# 4         False        False           False           False             True
#
#    marital_single  education_secondary  education_tertiary  region_Suburban  \
# 0           False                 True               False            False
# 1           False                 True               False            False
# 2           False                False               False            False
# 3           False                False                True            False
# 4           False                False                True            False
#
#    region_Urban
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#
# [5 rows x 54 columns]
# (9429, 54)

# %%
# Create a Scree Plot to decide the number of components to use
pca = PCA().fit(scaled_data)

plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Scree Plot')
plt.grid()
plt.show()

# %%
pca = PCA(n_components=40)  # Reduce to 40 dimensions (chosen from Scree Plot)
scaled_data_pca = pca.fit_transform(scaled_data)  # Transform data

# Compute hierarchical clustering
linkage_matrix = linkage(scaled_data_pca, method='ward')  # Ward's method for variance minimisation

# Plot dendrogram
plt.figure(figsize=(10, 5))
dendrogram(linkage_matrix)
plt.axhline(y=250, color='r', linestyle='--')  # Adjust threshold based on the plot
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Samples')
plt.ylabel('Distance')
plt.show()

# %%
# Assign cluster labels (decide number of clusters from dendrogram)
n_clusters = 3
cluster_labels = AgglomerativeClustering(n_clusters=n_clusters, linkage='ward').fit_predict(scaled_data_pca)

print(f"Cluster assignments: {np.unique(cluster_labels, return_counts=True)}")
cluster_labels
# Out:
# Cluster assignments: (array([0, 1, 2]), array([1260, 1796, 6373]))
# array([2, 2, 0, ..., 0, 2, 2])

# %%
# Merge cluster labels with the customer dataset
customer_data_with_labels = df_encoded
customer_data_with_labels['cluster'] = cluster_labels

# Count the numbers in each cluster
customer_data_with_labels['cluster'].value_counts()
# Out:
# cluster
# 2    6373
# 1    1796
# 0    1260
# Name: count, dtype: int64

# %%
# Find the most common traits of each cluster, and count of each traits
unique_traits = {}
for cluster_id in range(n_clusters):
    cluster_data = customer_data_with_labels[customer_data_with_labels['cluster'] == cluster_id]
    unique_traits[cluster_id] = cluster_data.drop(columns=['cluster']).mode().iloc[0]
    print(f"Cluster {cluster_id}:")
    print(unique_traits[cluster_id])
    print()
    print(f"Number of customers in cluster {cluster_id}: {len(cluster_data)}")
    print()
# Out:
# Cluster 0:
# age                                     23.0
# credit_default                           0.0
# income                                2270.0
# credit_card                              1.0
# personal_loan                            1.0
# mortgage                                 0.0
# savings_account                          1.0
# investment_product                       0.0
# auto_loan                                0.0
# wealth_management                        0.0
# days_since_last_transaction              0.0
# current_balance                          0.0
# peak_month                              12.0
# peak_month_spending                      0.0
# peak_month_frequency                    14.0
# total_transactions_3m                    0.0
# total_transactions_6m                    0.0
# total_transactions_12m                 130.0
# total_transaction_amount_3m              0.0
# total_transaction_amount_6m              0.0
# total_transaction_amount_12m             0.0
# average_transaction_amount_3m            0.0
# average_transaction_amount_6m            0.0
# average_transaction_amount_12m           0.0
# transaction_frequency_3m                 0.0
# transaction_frequency_6m                 0.0
# transaction_frequency_12m          10.833333
# high_value_transaction_rate_3m           0.0
# high_value_transaction_rate_6m           0.0
# high_value_transaction_rate_12m     0.076923
# online_transaction_ratio_3m              0.0
# online_transaction_ratio_6m              0.0
# online_transaction_ratio_12m        0.298947
# has_mobile_app                           1.0
# has_web_account                          1.0
# mobile_logins_per_week                   0.0
# web_logins_per_week                      8.0
# avg_mobile_session_duration              0.0
# avg_web_session_duration                 0.0
# job_blue-collar                        False
# job_entrepreneur                       False
# job_management                         False
# job_retired                            False
# job_self-employed                      False
# job_services                           False
# job_student                            False
# job_technician                         False
# job_unemployed                         False
# marital_married                        False
# marital_single                         False
# education_secondary                    False
# education_tertiary                     False
# region_Suburban                        False
# region_Urban                            True
# Name: 0, dtype: object
#
# Number of customers in cluster 0: 1260
#
# Cluster 1:
# age                                        39.0
# credit_default                              0.0
# income                                   5921.0
# credit_card                                 1.0
# personal_loan                               1.0
# mortgage                                    1.0
# savings_account                             1.0
# investment_product                          1.0
# auto_loan                                   1.0
# wealth_management                           0.0
# days_since_last_transaction                 0.0
# current_balance                     1791.460858
# peak_month                                 12.0
# peak_month_spending                 3480.546553
# peak_month_frequency                       53.0
# total_transactions_3m                     130.0
# total_transactions_6m                     252.0
# total_transactions_12m                    513.0
# total_transaction_amount_3m         7304.996591
# total_transaction_amount_6m         10946.22589
# total_transaction_amount_12m       19463.507435
# average_transaction_amount_3m         77.773933
# average_transaction_amount_6m         34.965783
# average_transaction_amount_12m        36.805618
# transaction_frequency_3m              43.333333
# transaction_frequency_6m                   42.0
# transaction_frequency_12m                 42.75
# high_value_transaction_rate_3m         0.142857
# high_value_transaction_rate_6m            0.125
# high_value_transaction_rate_12m           0.125
# online_transaction_ratio_3m            0.432408
# online_transaction_ratio_6m            0.389979
# online_transaction_ratio_12m           0.447084
# has_mobile_app                              1.0
# has_web_account                             1.0
# mobile_logins_per_week                      6.0
# web_logins_per_week                         5.0
# avg_mobile_session_duration                 0.0
# avg_web_session_duration                    0.0
# job_blue-collar                           False
# job_entrepreneur                          False
# job_management                             True
# job_retired                               False
# job_self-employed                         False
# job_services                              False
# job_student                               False
# job_technician                            False
# job_unemployed                            False
# marital_married                            True
# marital_single                            False
# education_secondary                       False
# education_tertiary                         True
# region_Suburban                           False
# region_Urban                               True
# Name: 0, dtype: object
#
# Number of customers in cluster 1: 1796
#
# Cluster 2:
# age                                      46.0
# credit_default                            0.0
# income                                 2628.0
# credit_card                               1.0
# personal_loan                             1.0
# mortgage                                  1.0
# savings_account                           1.0
# investment_product                        0.0
# auto_loan                                 1.0
# wealth_management                         0.0
# days_since_last_transaction               0.0
# current_balance                     68.336448
# peak_month                               12.0
# peak_month_spending                 71.520765
# peak_month_frequency                     44.0
# total_transactions_3m                     0.0
# total_transactions_6m                     0.0
# total_transactions_12m                  434.0
# total_transaction_amount_3m               0.0
# total_transaction_amount_6m               0.0
# total_transaction_amount_12m       324.215495
# average_transaction_amount_3m             0.0
# average_transaction_amount_6m             0.0
# average_transaction_amount_12m       1.045856
# transaction_frequency_3m                  0.0
# transaction_frequency_6m                  0.0
# transaction_frequency_12m           36.166667
# high_value_transaction_rate_3m            0.0
# high_value_transaction_rate_6m            0.0
# high_value_transaction_rate_12m      0.083333
# online_transaction_ratio_3m               0.0
# online_transaction_ratio_6m               0.0
# online_transaction_ratio_12m         0.352951
# has_mobile_app                            1.0
# has_web_account                           1.0
# mobile_logins_per_week                    6.0
# web_logins_per_week                       5.0
# avg_mobile_session_duration               0.0
# avg_web_session_duration                  0.0
# job_blue-collar                         False
# job_entrepreneur                        False
# job_management                          False
# job_retired                             False
# job_self-employed                       False
# job_services                            False
# job_student                             False
# job_technician                          False
# job_unemployed                          False
# marital_married                          True
# marital_single                          False
# education_secondary                     False
# education_tertiary                      False
# region_Suburban                         False
# region_Urban                             True
# Name: 0, dtype: object
#
# Number of customers in cluster 2: 6373

# %%
# Each cluster statistical distributions

# For cluster 0
cluster_0_data = customer_data_with_labels[customer_data_with_labels['cluster'] == 0]
print('For Cluster 0')
print(cluster_0_data.describe()) # Mean income of $1255

# For cluster 1
cluster_1_data = customer_data_with_labels[customer_data_with_labels['cluster'] == 1]
print('For Cluster 1')
print(cluster_1_data.describe()) # Mean income of $6293

# For cluster 2
cluster_2_data = customer_data_with_labels[customer_data_with_labels['cluster'] == 2]
print('For Cluster 2')
print(cluster_2_data.describe()) # Mean income of $3085
# Out:
# For Cluster 0
#                age  credit_default       income  credit_card  personal_loan  \
# count  1260.000000     1260.000000  1260.000000  1260.000000    1260.000000
# mean     51.757143        0.037302  1255.966667     0.634127       0.692857
# std      22.629553        0.189575   948.001771     0.481865       0.461492
# min      21.000000        0.000000     0.000000     0.000000       0.000000
# 25%      26.000000        0.000000   460.500000     0.000000       0.000000
# 50%      54.000000        0.000000   931.000000     1.000000       1.000000
# 75%      71.000000        0.000000  2064.250000     1.000000       1.000000
# max      99.000000        1.000000  7722.000000     1.000000       1.000000
#
#           mortgage  savings_account  investment_product    auto_loan  \
# count  1260.000000      1260.000000         1260.000000  1260.000000
# mean      0.426984         0.847619            0.270635     0.469048
# std       0.494836         0.359532            0.444464     0.499239
# min       0.000000         0.000000            0.000000     0.000000
# 25%       0.000000         1.000000            0.000000     0.000000
# 50%       0.000000         1.000000            0.000000     0.000000
# 75%       1.000000         1.000000            1.000000     1.000000
# max       1.000000         1.000000            1.000000     1.000000
#
#        wealth_management  ...  online_transaction_ratio_3m  \
# count        1260.000000  ...                  1260.000000
# mean            0.219841  ...                     0.528015
# std             0.414303  ...                     0.176427
# min             0.000000  ...                     0.000000
# 25%             0.000000  ...                     0.454243
# 50%             0.000000  ...                     0.555801
# 75%             0.000000  ...                     0.649003
# max             1.000000  ...                     0.827326
#
#        online_transaction_ratio_6m  online_transaction_ratio_12m  \
# count                  1260.000000                   1260.000000
# mean                      0.540642                      0.563042
# std                       0.156886                      0.111098
# min                       0.000000                      0.298947
# 25%                       0.452097                      0.465307
# 50%                       0.566211                      0.564176
# 75%                       0.651705                      0.651652
# max                       0.835170                      0.844852
#
#        has_mobile_app  has_web_account  mobile_logins_per_week  \
# count     1260.000000      1260.000000             1260.000000
# mean         0.791270         0.837302                6.154762
# std          0.406562         0.369237                3.733031
# min          0.000000         0.000000                0.000000
# 25%          1.000000         1.000000                5.000000
# 50%          1.000000         1.000000                6.000000
# 75%          1.000000         1.000000                9.000000
# max          1.000000         1.000000               13.000000
#
#        web_logins_per_week  avg_mobile_session_duration  \
# count          1260.000000                  1260.000000
# mean              5.501587                     2.833968
# std               2.894353                     1.980654
# min               0.000000                     0.000000
# 25%               4.000000                     1.100000
# 50%               6.000000                     3.100000
# 75%               8.000000                     4.400000
# max              10.000000                     8.300000
#
#        avg_web_session_duration  cluster
# count               1260.000000   1260.0
# mean                   4.558571      0.0
# std                    2.769357      0.0
# min                    0.000000      0.0
# 25%                    2.800000      0.0
# 50%                    5.000000      0.0
# 75%                    6.600000      0.0
# max                   11.700000      0.0
#
# [8 rows x 40 columns]
# For Cluster 1
#                age  credit_default        income  credit_card  personal_loan  \
# count  1796.000000     1796.000000   1796.000000  1796.000000    1796.000000
# mean     45.124722        0.022272   6293.330735     0.891425       0.533964
# std      12.046846        0.147607   2175.742873     0.311191       0.498984
# min      21.000000        0.000000   1519.000000     0.000000       0.000000
# 25%      37.000000        0.000000   4826.750000     1.000000       0.000000
# 50%      44.000000        0.000000   6273.000000     1.000000       1.000000
# 75%      53.000000        0.000000   8120.000000     1.000000       1.000000
# max      99.000000        1.000000  14272.000000     1.000000       1.000000
#
#           mortgage  savings_account  investment_product    auto_loan  \
# count  1796.000000      1796.000000         1796.000000  1796.000000
# mean      0.608018         0.905902            0.566258     0.729955
# std       0.488329         0.292046            0.495728     0.444106
# min       0.000000         0.000000            0.000000     0.000000
# 25%       0.000000         1.000000            0.000000     0.000000
# 50%       1.000000         1.000000            1.000000     1.000000
# 75%       1.000000         1.000000            1.000000     1.000000
# max       1.000000         1.000000            1.000000     1.000000
#
#        wealth_management  ...  online_transaction_ratio_3m  \
# count        1796.000000  ...                  1796.000000
# mean            0.423719  ...                     0.688766
# std             0.494285  ...                     0.070626
# min             0.000000  ...                     0.432408
# 25%             0.000000  ...                     0.655380
# 50%             0.000000  ...                     0.697169
# 75%             1.000000  ...                     0.735519
# max             1.000000  ...                     0.863008
#
#        online_transaction_ratio_6m  online_transaction_ratio_12m  \
# count                  1796.000000                   1796.000000
# mean                      0.691835                      0.688849
# std                       0.070245                      0.068405
# min                       0.389979                      0.447084
# 25%                       0.659087                      0.656552
# 50%                       0.699814                      0.696137
# 75%                       0.738586                      0.733717
# max                       0.866541                      0.881280
#
#        has_mobile_app  has_web_account  mobile_logins_per_week  \
# count     1796.000000      1796.000000             1796.000000
# mean         0.841314         0.844098                6.817372
# std          0.365485         0.362863                3.684047
# min          0.000000         0.000000                0.000000
# 25%          1.000000         1.000000                6.000000
# 50%          1.000000         1.000000                7.000000
# 75%          1.000000         1.000000               10.000000
# max          1.000000         1.000000               14.000000
#
#        web_logins_per_week  avg_mobile_session_duration  \
# count          1796.000000                  1796.000000
# mean              4.963808                     3.129399
# std               2.608391                     1.993151
# min               0.000000                     0.000000
# 25%               4.000000                     1.700000
# 50%               5.000000                     3.400000
# 75%               7.000000                     4.600000
# max              11.000000                     8.800000
#
#        avg_web_session_duration  cluster
# count               1796.000000   1796.0
# mean                   4.459243      1.0
# std                    2.693508      0.0
# min                    0.000000      1.0
# 25%                    2.700000      1.0
# 50%                    4.800000      1.0
# 75%                    6.400000      1.0
# max                   11.700000      1.0
#
# [8 rows x 40 columns]
# For Cluster 2
#                age  credit_default       income  credit_card  personal_loan  \
# count  6373.000000     6373.000000  6373.000000  6373.000000    6373.000000
# mean     45.546838        0.038757  3085.922015     0.863957       0.619332
# std      11.700994        0.193031  1058.142119     0.342861       0.485589
# min      21.000000        0.000000    37.000000     0.000000       0.000000
# 25%      37.000000        0.000000  2386.000000     1.000000       0.000000
# 50%      45.000000        0.000000  3153.000000     1.000000       1.000000
# 75%      53.000000        0.000000  3780.000000     1.000000       1.000000
# max      99.000000        1.000000  9967.000000     1.000000       1.000000
#
#           mortgage  savings_account  investment_product    auto_loan  \
# count  6373.000000      6373.000000         6373.000000  6373.000000
# mean      0.503217         0.904754            0.288718     0.717245
# std       0.500029         0.293577            0.453202     0.450374
# min       0.000000         0.000000            0.000000     0.000000
# 25%       0.000000         1.000000            0.000000     0.000000
# 50%       1.000000         1.000000            0.000000     1.000000
# 75%       1.000000         1.000000            1.000000     1.000000
# max       1.000000         1.000000            1.000000     1.000000
#
#        wealth_management  ...  online_transaction_ratio_3m  \
# count        6373.000000  ...                  6373.000000
# mean            0.220775  ...                     0.621977
# std             0.414802  ...                     0.125096
# min             0.000000  ...                     0.000000
# 25%             0.000000  ...                     0.599222
# 50%             0.000000  ...                     0.645172
# 75%             0.000000  ...                     0.683116
# max             1.000000  ...                     0.861424
#
#        online_transaction_ratio_6m  online_transaction_ratio_12m  \
# count                  6373.000000                   6373.000000
# mean                      0.622404                      0.639991
# std                       0.123605                      0.069088
# min                       0.000000                      0.352951
# 25%                       0.601070                      0.606363
# 50%                       0.644419                      0.647229
# 75%                       0.683718                      0.685177
# max                       0.860083                      0.865623
#
#        has_mobile_app  has_web_account  mobile_logins_per_week  \
# count     6373.000000      6373.000000             6373.000000
# mean         0.833203         0.849521                6.222815
# std          0.372824         0.357568                3.427429
# min          0.000000         0.000000                0.000000
# 25%          1.000000         1.000000                5.000000
# 50%          1.000000         1.000000                6.000000
# 75%          1.000000         1.000000                9.000000
# max          1.000000         1.000000               14.000000
#
#        web_logins_per_week  avg_mobile_session_duration  \
# count          6373.000000                  6373.000000
# mean              5.065275                     3.047199
# std               2.605973                     1.974357
# min               0.000000                     0.000000
# 25%               4.000000                     1.600000
# 50%               5.000000                     3.200000
# 75%               7.000000                     4.500000
# max              10.000000                     9.200000
#
#        avg_web_session_duration  cluster
# count               6373.000000   6373.0
# mean                   4.480104      2.0
# std                    2.652818      0.0
# min                    0.000000      2.0
# 25%                    2.900000      2.0
# 50%                    4.800000      2.0
# 75%                    6.400000      2.0
# max                   12.200000      2.0
#
# [8 rows x 40 columns]

# %%
# Visualise the different clusters of Age against Income

# Define colors for clusters
colors = ['blue', 'green', 'orange']

# Create figure
plt.figure(figsize=(10, 6))

# Scatter plots for each cluster with transparency
plt.scatter(cluster_0_data['income'], cluster_0_data['age'], label='Cluster 0', color=colors[0], alpha=0.5)
plt.scatter(cluster_1_data['income'], cluster_1_data['age'], label='Cluster 1', color=colors[1], alpha=0.5)
plt.scatter(cluster_2_data['income'], cluster_2_data['age'], label='Cluster 2', color=colors[2], alpha=0.5)

# Compute cluster centroids
centroids = np.array([
    [cluster_0_data['income'].mean(), cluster_0_data['age'].mean()],
    [cluster_1_data['income'].mean(), cluster_1_data['age'].mean()],
    [cluster_2_data['income'].mean(), cluster_2_data['age'].mean()]
])

# Plot centroids in respective cluster colors
plt.scatter(centroids[:, 0], centroids[:, 1], color=colors, s=200, marker='X', edgecolors='black')

# Create a custom legend handle for centroids (black color)
centroid_legend = mlines.Line2D([], [], color='black', marker='X', linestyle='None', markersize=10, label='Centroids')

# Add legend with custom centroid handle
plt.xlabel('Income')
plt.ylabel('Age')
plt.title('Income vs. Age for Each Cluster')
plt.legend(handles=[plt.Line2D([0], [0], color=color, marker='o', linestyle='None', markersize=8, label=f'Cluster {i}') for i, color in enumerate(colors)] + [centroid_legend])
plt.show()

# %% [markdown]
# Now we will move on to KMeans Clustering

# %%
# Find the optimal number of clusters for KMeans
silhouette_scores = []
cluster_range = range(2, 10)  # Start from 3 clusters to max 9 clusters

for n_clusters in cluster_range:
    kmeans = KMeans(n_clusters=n_clusters, random_state=42, n_init=10)
    cluster_labels = kmeans.fit_predict(scaled_data_pca)

    # Calculate Silhouette Score
    silhouette_avg = silhouette_score(scaled_data_pca, cluster_labels)
    silhouette_scores.append(silhouette_avg)

# Plot Silhouette Score
plt.subplot(1, 2, 2)
plt.plot(cluster_range, silhouette_scores, marker='o', color='r')
plt.title('Silhouette Score')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.tight_layout()
plt.show()

# %%
# K-means Clustering
# Apply K-Means with chosen K (K=3)
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
cluster_labels = kmeans.fit_predict(scaled_data_pca)

# Add cluster labels to the dataset
customer_data_with_labels_kmean = df_encoded
customer_data_with_labels_kmean['Cluster'] = cluster_labels

# Find the most common traits of each cluster, and count of each traits
unique_traits = {}
n_clusters = 3
for cluster_id in range(n_clusters):
    cluster_data = customer_data_with_labels_kmean[customer_data_with_labels_kmean['Cluster'] == cluster_id]
    unique_traits[cluster_id] = cluster_data.drop(columns=['Cluster']).mode().iloc[0]
    print(f"Cluster {cluster_id}:")
    print(unique_traits[cluster_id])
    print()
    print(f"Number of customers in cluster {cluster_id}: {len(cluster_data)}")
    print()

# Each cluster statistical distributions
# For cluster 0
cluster_0_data = customer_data_with_labels_kmean[customer_data_with_labels_kmean['Cluster'] == 0]
print('For Cluster 0')
print(cluster_0_data.describe()) # Mean income of $3000

# For cluster 1
cluster_1_data = customer_data_with_labels_kmean[customer_data_with_labels_kmean['Cluster'] == 1]
print('For Cluster 1')
print(cluster_1_data.describe()) # Mean income of $2087

# For cluster 2
cluster_2_data = customer_data_with_labels_kmean[customer_data_with_labels_kmean['Cluster'] == 2]
print('For Cluster 2')
print(cluster_2_data.describe()) # Mean income of $7119
# Out:
# Cluster 0:
# age                                     46.0
# credit_default                           0.0
# income                                2628.0
# credit_card                              1.0
# personal_loan                            1.0
# mortgage                                 1.0
# savings_account                          1.0
# investment_product                       0.0
# auto_loan                                1.0
# wealth_management                        0.0
# days_since_last_transaction              0.0
# current_balance                          0.0
# peak_month                              12.0
# peak_month_spending                      0.0
# peak_month_frequency                    44.0
# total_transactions_3m                  101.0
# total_transactions_6m                  188.0
# total_transactions_12m                 416.0
# total_transaction_amount_3m              0.0
# total_transaction_amount_6m              0.0
# total_transaction_amount_12m             0.0
# average_transaction_amount_3m            0.0
# average_transaction_amount_6m            0.0
# average_transaction_amount_12m           0.0
# transaction_frequency_3m           33.666667
# transaction_frequency_6m           31.333333
# transaction_frequency_12m          34.666667
# high_value_transaction_rate_3m      0.090909
# high_value_transaction_rate_6m      0.090909
# high_value_transaction_rate_12m     0.083333
# online_transaction_ratio_3m              0.0
# online_transaction_ratio_6m              0.0
# online_transaction_ratio_12m        0.406853
# has_mobile_app                           1.0
# has_web_account                          1.0
# mobile_logins_per_week                   6.0
# web_logins_per_week                      5.0
# avg_mobile_session_duration              0.0
# avg_web_session_duration                 0.0
# job_blue-collar                        False
# job_entrepreneur                       False
# job_management                         False
# job_retired                            False
# job_self-employed                      False
# job_services                           False
# job_student                            False
# job_technician                         False
# job_unemployed                         False
# marital_married                         True
# marital_single                         False
# education_secondary                    False
# education_tertiary                     False
# region_Suburban                        False
# region_Urban                            True
# cluster                                  2.0
# Name: 0, dtype: object
#
# Number of customers in cluster 0: 6234
#
# Cluster 1:
# age                                     61.0
# credit_default                           0.0
# income                                2270.0
# credit_card                              1.0
# personal_loan                            1.0
# mortgage                                 0.0
# savings_account                          1.0
# investment_product                       0.0
# auto_loan                                1.0
# wealth_management                        0.0
# days_since_last_transaction              0.0
# current_balance                          0.0
# peak_month                              12.0
# peak_month_spending                      0.0
# peak_month_frequency                    28.0
# total_transactions_3m                    0.0
# total_transactions_6m                    0.0
# total_transactions_12m                 130.0
# total_transaction_amount_3m              0.0
# total_transaction_amount_6m              0.0
# total_transaction_amount_12m             0.0
# average_transaction_amount_3m            0.0
# average_transaction_amount_6m            0.0
# average_transaction_amount_12m           0.0
# transaction_frequency_3m                 0.0
# transaction_frequency_6m                 0.0
# transaction_frequency_12m          10.833333
# high_value_transaction_rate_3m           0.0
# high_value_transaction_rate_6m           0.0
# high_value_transaction_rate_12m     0.076923
# online_transaction_ratio_3m              0.0
# online_transaction_ratio_6m              0.0
# online_transaction_ratio_12m        0.298947
# has_mobile_app                           1.0
# has_web_account                          1.0
# mobile_logins_per_week                   0.0
# web_logins_per_week                      8.0
# avg_mobile_session_duration              0.0
# avg_web_session_duration                 0.0
# job_blue-collar                        False
# job_entrepreneur                       False
# job_management                         False
# job_retired                            False
# job_self-employed                      False
# job_services                           False
# job_student                            False
# job_technician                         False
# job_unemployed                         False
# marital_married                         True
# marital_single                         False
# education_secondary                    False
# education_tertiary                     False
# region_Suburban                        False
# region_Urban                            True
# cluster                                  0.0
# Name: 0, dtype: object
#
# Number of customers in cluster 1: 1768
#
# Cluster 2:
# age                                        48.0
# credit_default                              0.0
# income                                   5921.0
# credit_card                                 1.0
# personal_loan                               1.0
# mortgage                                    1.0
# savings_account                             1.0
# investment_product                          1.0
# auto_loan                                   1.0
# wealth_management                           0.0
# days_since_last_transaction                 0.0
# current_balance                     3774.374692
# peak_month                                 12.0
# peak_month_spending                 5417.369485
# peak_month_frequency                       53.0
# total_transactions_3m                     128.0
# total_transactions_6m                     232.0
# total_transactions_12m                    507.0
# total_transaction_amount_3m                 0.0
# total_transaction_amount_6m                 0.0
# total_transaction_amount_12m       30034.787833
# average_transaction_amount_3m               0.0
# average_transaction_amount_6m               0.0
# average_transaction_amount_12m        56.041903
# transaction_frequency_3m              42.666667
# transaction_frequency_6m              38.666667
# transaction_frequency_12m                 42.25
# high_value_transaction_rate_3m         0.142857
# high_value_transaction_rate_6m              0.0
# high_value_transaction_rate_12m        0.142857
# online_transaction_ratio_3m                 0.0
# online_transaction_ratio_6m                 0.0
# online_transaction_ratio_12m           0.447084
# has_mobile_app                              1.0
# has_web_account                             1.0
# mobile_logins_per_week                      7.0
# web_logins_per_week                         5.0
# avg_mobile_session_duration                 0.0
# avg_web_session_duration                    0.0
# job_blue-collar                           False
# job_entrepreneur                          False
# job_management                             True
# job_retired                               False
# job_self-employed                         False
# job_services                              False
# job_student                               False
# job_technician                            False
# job_unemployed                            False
# marital_married                            True
# marital_single                            False
# education_secondary                       False
# education_tertiary                         True
# region_Suburban                           False
# region_Urban                               True
# cluster                                     1.0
# Name: 0, dtype: object
#
# Number of customers in cluster 2: 1427
#
# For Cluster 0
#                age  credit_default       income  credit_card  personal_loan  \
# count  6234.000000     6234.000000  6234.000000  6234.000000    6234.000000
# mean     42.842958        0.034970  3000.080045     0.855791       0.623677
# std      10.624411        0.183717  1098.290971     0.351330       0.484502
# min      21.000000        0.000000     0.000000     0.000000       0.000000
# 25%      35.000000        0.000000  2254.500000     1.000000       0.000000
# 50%      43.000000        0.000000  3121.000000     1.000000       1.000000
# 75%      51.000000        0.000000  3765.000000     1.000000       1.000000
# max      99.000000        1.000000  8183.000000     1.000000       1.000000
#
#           mortgage  savings_account  investment_product    auto_loan  \
# count  6234.000000      6234.000000         6234.000000  6234.000000
# mean      0.505454         0.900064            0.294354     0.709336
# std       0.500010         0.299938            0.455788     0.454105
# min       0.000000         0.000000            0.000000     0.000000
# 25%       0.000000         1.000000            0.000000     0.000000
# 50%       1.000000         1.000000            0.000000     1.000000
# 75%       1.000000         1.000000            1.000000     1.000000
# max       1.000000         1.000000            1.000000     1.000000
#
#        wealth_management  ...  online_transaction_ratio_6m  \
# count        6234.000000  ...                  6234.000000
# mean            0.231152  ...                     0.655173
# std             0.421603  ...                     0.066149
# min             0.000000  ...                     0.000000
# 25%             0.000000  ...                     0.619820
# 50%             0.000000  ...                     0.657432
# 75%             0.000000  ...                     0.694870
# max             1.000000  ...                     0.860083
#
#        online_transaction_ratio_12m  has_mobile_app  has_web_account  \
# count                   6234.000000     6234.000000      6234.000000
# mean                       0.656692        0.855470         0.846968
# std                        0.057181        0.351655         0.360047
# min                        0.406853        0.000000         0.000000
# 25%                        0.621277        1.000000         1.000000
# 50%                        0.657114        1.000000         1.000000
# 75%                        0.694594        1.000000         1.000000
# max                        0.881280        1.000000         1.000000
#
#        mobile_logins_per_week  web_logins_per_week  \
# count             6234.000000          6234.000000
# mean                 6.574110             4.866218
# std                  3.398083             2.506543
# min                  0.000000             0.000000
# 25%                  5.000000             4.000000
# 50%                  7.000000             5.000000
# 75%                  9.000000             6.000000
# max                 14.000000            10.000000
#
#        avg_mobile_session_duration  avg_web_session_duration      cluster  \
# count                  6234.000000               6234.000000  6234.000000
# mean                      3.083863                  4.403272     1.833494
# std                       1.924986                  2.631992     0.479178
# min                       0.000000                  0.000000     0.000000
# 25%                       1.800000                  2.800000     2.000000
# 50%                       3.200000                  4.700000     2.000000
# 75%                       4.500000                  6.300000     2.000000
# max                       9.200000                 12.200000     2.000000
#
#        Cluster
# count   6234.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
#
# [8 rows x 41 columns]
# For Cluster 1
#                age  credit_default       income  credit_card  personal_loan  \
# count  1768.000000     1768.000000  1768.000000  1768.000000    1768.000000
# mean     60.309389        0.042986  2087.102376     0.722851       0.657805
# std      16.701137        0.202884  1282.581703     0.447717       0.474579
# min      21.000000        0.000000     0.000000     0.000000       0.000000
# 25%      48.000000        0.000000   902.750000     0.000000       0.000000
# 50%      63.000000        0.000000  2148.000000     1.000000       1.000000
# 75%      70.000000        0.000000  2918.500000     1.000000       1.000000
# max      99.000000        1.000000  9777.000000     1.000000       1.000000
#
#           mortgage  savings_account  investment_product    auto_loan  \
# count  1768.000000      1768.000000         1768.000000  1768.000000
# mean      0.443439         0.883484            0.278281     0.563348
# std       0.496931         0.320933            0.448279     0.496111
# min       0.000000         0.000000            0.000000     0.000000
# 25%       0.000000         1.000000            0.000000     0.000000
# 50%       0.000000         1.000000            0.000000     1.000000
# 75%       1.000000         1.000000            1.000000     1.000000
# max       1.000000         1.000000            1.000000     1.000000
#
#        wealth_management  ...  online_transaction_ratio_6m  \
# count        1768.000000  ...                  1768.000000
# mean            0.191742  ...                     0.467841
# std             0.393783  ...                     0.182312
# min             0.000000  ...                     0.000000
# 25%             0.000000  ...                     0.435865
# 50%             0.000000  ...                     0.499815
# 75%             0.000000  ...                     0.579796
# max             1.000000  ...                     0.764070
#
#        online_transaction_ratio_12m  has_mobile_app  has_web_account  \
# count                   1768.000000     1768.000000      1768.000000
# mean                       0.533618        0.711538         0.855769
# std                        0.089833        0.453175         0.351423
# min                        0.298947        0.000000         0.000000
# 25%                        0.463783        0.000000         1.000000
# 50%                        0.523168        1.000000         1.000000
# 75%                        0.604437        1.000000         1.000000
# max                        0.834324        1.000000         1.000000
#
#        mobile_logins_per_week  web_logins_per_week  \
# count             1768.000000          1768.000000
# mean                 4.847285             6.152715
# std                  3.482738             2.916569
# min                  0.000000             0.000000
# 25%                  0.000000             5.000000
# 50%                  6.000000             7.000000
# 75%                  7.000000             8.000000
# max                 13.000000            10.000000
#
#        avg_mobile_session_duration  avg_web_session_duration      cluster  \
# count                  1768.000000               1768.000000  1768.000000
# mean                      2.714367                  4.862613     0.888009
# std                       2.145125                  2.749887     0.990568
# min                       0.000000                  0.000000     0.000000
# 25%                       0.000000                  3.200000     0.000000
# 50%                       2.900000                  5.300000     0.000000
# 75%                       4.425000                  6.825000     2.000000
# max                       8.500000                 12.200000     2.000000
#
#        Cluster
# count   1768.0
# mean       1.0
# std        0.0
# min        1.0
# 25%        1.0
# 50%        1.0
# 75%        1.0
# max        1.0
#
# [8 rows x 41 columns]
# For Cluster 2
#                age  credit_default        income  credit_card  personal_loan  \
# count  1427.000000     1427.000000   1427.000000  1427.000000    1427.000000
# mean     44.021023        0.028031   7119.428872     0.906097       0.510161
# std      11.721385        0.165119   1676.463747     0.291796       0.500072
# min      21.000000        0.000000   3083.000000     0.000000       0.000000
# 25%      36.000000        0.000000   5761.500000     1.000000       0.000000
# 50%      44.000000        0.000000   7072.000000     1.000000       1.000000
# 75%      52.000000        0.000000   8549.000000     1.000000       1.000000
# max      99.000000        1.000000  14272.000000     1.000000       1.000000
#
#           mortgage  savings_account  investment_product    auto_loan  \
# count  1427.000000      1427.000000         1427.000000  1427.000000
# mean      0.632095         0.902593            0.610371     0.739313
# std       0.482404         0.296615            0.487837     0.439163
# min       0.000000         0.000000            0.000000     0.000000
# 25%       0.000000         1.000000            0.000000     0.000000
# 50%       1.000000         1.000000            1.000000     1.000000
# 75%       1.000000         1.000000            1.000000     1.000000
# max       1.000000         1.000000            1.000000     1.000000
#
#        wealth_management  ...  online_transaction_ratio_6m  \
# count        1427.000000  ...                  1427.000000
# mean            0.466013  ...                     0.685937
# std             0.499018  ...                     0.097601
# min             0.000000  ...                     0.000000
# 25%             0.000000  ...                     0.658374
# 50%             0.000000  ...                     0.697551
# 75%             1.000000  ...                     0.737326
# max             1.000000  ...                     0.866541
#
#        online_transaction_ratio_12m  has_mobile_app  has_web_account  \
# count                   1427.000000     1427.000000      1427.000000
# mean                       0.692374        0.859846         0.835319
# std                        0.063785        0.347269         0.371023
# min                        0.447084        0.000000         0.000000
# 25%                        0.658058        1.000000         1.000000
# 50%                        0.696683        1.000000         1.000000
# 75%                        0.734590        1.000000         1.000000
# max                        0.857861        1.000000         1.000000
#
#        mobile_logins_per_week  web_logins_per_week  \
# count             1427.000000           1427.00000
# mean                 7.080589              4.84513
# std                  3.634004              2.60714
# min                  0.000000              0.00000
# 25%                  6.000000              4.00000
# 50%                  7.000000              5.00000
# 75%                 10.000000              6.00000
# max                 14.000000             11.00000
#
#        avg_mobile_session_duration  avg_web_session_duration      cluster  \
# count                  1427.000000               1427.000000  1427.000000
# mean                      3.214576                  4.384863     1.080589
# std                       1.964980                  2.736803     0.272298
# min                       0.000000                  0.000000     1.000000
# 25%                       1.900000                  2.500000     1.000000
# 50%                       3.400000                  4.700000     1.000000
# 75%                       4.650000                  6.400000     1.000000
# max                       8.800000                 11.700000     2.000000
#
#        Cluster
# count   1427.0
# mean       2.0
# std        0.0
# min        2.0
# 25%        2.0
# 50%        2.0
# 75%        2.0
# max        2.0
#
# [8 rows x 41 columns]

# %%
# Visualise the different clusters of Age against Income

# Define colors for clusters
colors = ['blue', 'green', 'orange']

# Create figure
plt.figure(figsize=(10, 6))

# Scatter plots for each cluster with transparency
plt.scatter(cluster_0_data['income'], cluster_0_data['age'], label='Cluster 0', color=colors[0], alpha=0.5)
plt.scatter(cluster_1_data['income'], cluster_1_data['age'], label='Cluster 1', color=colors[1], alpha=0.5)
plt.scatter(cluster_2_data['income'], cluster_2_data['age'], label='Cluster 2', color=colors[2], alpha=0.5)

# Compute cluster centroids
centroids = np.array([
    [cluster_0_data['income'].mean(), cluster_0_data['age'].mean()],
    [cluster_1_data['income'].mean(), cluster_1_data['age'].mean()],
    [cluster_2_data['income'].mean(), cluster_2_data['age'].mean()]
])

# Plot centroids in respective cluster colors
plt.scatter(centroids[:, 0], centroids[:, 1], color=colors, s=200, marker='X', edgecolors='black')

# Create a custom legend handle for centroids (black color)
centroid_legend = mlines.Line2D([], [], color='black', marker='X', linestyle='None', markersize=10, label='Centroids')

# Add legend with custom centroid handle
plt.xlabel('Income')
plt.ylabel('Age')
plt.title('Income vs. Age for Each Cluster')
plt.legend(handles=[plt.Line2D([0], [0], color=color, marker='o', linestyle='None', markersize=8, label=f'Cluster {i}') for i, color in enumerate(colors)] + [centroid_legend])
plt.show()

# %% [markdown]
# ### Conclusion for Existing Customers Segments
# Both K-Means and hierarchical clustering are able to segments the clusters well. But hierarchical edges over k-means due to slightly clearer segmentation and its robustness to outliers as compared to K-means. Additionally, hierarchical clustering can handle mixed data types better, and has no assumption on equal sized clusters (KMeans have the tendancy to create equally sized clusters). As such, hierarchical clustering will be chosen to segment existing customers.

# %% [markdown]
# # 7. BIRCH Real-time Segmentation
#
# Because Hierarchical Clustering and KMeans do not naturally support real-time segmentation, we shall explore BIRCH as a means to do so. The advantage of BIRCH as an algorithm is is able to update clusters incrementally with incoming data, making them more suitable for large datasets. We shall now test this algorithm with our dataset.

# %%
# Train BIRCH on historical data
birch = Birch(threshold=0.5, branching_factor=50, n_clusters=3) # Number of clusters are decided from hierarchical clustering results
birch.fit(scaled_data_pca)

birch_labels = birch.predict(scaled_data_pca)
print(birch_labels)
# Out:
# [2 2 0 ... 0 2 2]

# %%
# Get subclusters
subcluster_centers = birch.subcluster_centers_

# Perform hierarchical clustering on subclusters
Z = linkage(subcluster_centers, method='ward')

# Plot dendrogram
plt.figure(figsize=(10, 6))
dendrogram(Z)
plt.axhline(y=250, color='r', linestyle='--')  # Adjust threshold based on the plot
plt.title("Dendrogram of BIRCH Subclusters")
plt.xlabel("Subcluster Index")
plt.ylabel("Distance")
plt.show()

# %% [markdown]
# We can now test BIRCH's real-time segmentation capabilities by testing a singular sample of data.

# %%
# Test the real-time segmentation capabilities of BIRCH
sample_data = scaled_data_pca[900,].reshape(1, -1) # Take a random sample from the dataset or create a new sample

# Test the row
predicted_cluster = birch.predict(sample_data)
print(f"Tested row assigned to cluster: {predicted_cluster[0]}")
# Out:
# Tested row assigned to cluster: 1
